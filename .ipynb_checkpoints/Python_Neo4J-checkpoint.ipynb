# %%
import json
import csv
import pandas as pd
# from py2neo import Graph

from resolve_coreference import AllenCR
from utils.spell_check import levenshtein_ratio_and_distance

# %%
dataset = r"data/input/dataset.json"

# neo4j database connection
# graph = Graph("bolt://localhost:7687", auth=("neo4j", "erclab"))

# test connection
# graph.run("UNWIND range(1, 3) AS n RETURN n, n * n as n_sq")

# %%
''' open restaurant dataset '''
file = open(dataset,)
restaurant_data = json.load(file)
file.close()

# restaurant = restaurant_data['restaurants'][0]
# print(restaurant)

# %%
from neo4j import GraphDatabase

class GraphDB:

    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        self.driver.close()

    def print_greeting(self, message):
        with self.driver.session() as session:
            greeting = session.write_transaction(self._create_and_return_greeting, message)
            print(greeting)

    @staticmethod
    def _create_and_return_greeting(tx, message):
        result = tx.run("CREATE (a:Greeting) "
                        "SET a.message = $message "
                        "RETURN a.message + ', from node ' + id(a)", message=message)
        return result.single()[0]
    
    ######################################### Creating Nodes ############################################
    
    # `Restaurant` Node
    def create_restaurant(self, rest_id, name, address, postal_code, rating):
        with self.driver.session() as session:
            restaurant = session.write_transaction(self._create_restaurant, rest_id, name, 
                                                   address, postal_code, rating)
            print(restaurant)
    
    @staticmethod
    def _create_restaurant(tx, rest_id, name, address, postal_code, rating):
        result = tx.run("CREATE (rest:Restaurant) "
                        "SET rest.rest_id = $rest_id, rest.name = $name, "
                        "rest.address = $address, rest.postal_code = $postal_code, rest.rating = $rating "
                        "RETURN rest.rest_id + ', from node ' + id(rest)", rest_id=rest_id, name=name, 
                        address=address, postal_code=postal_code, rating=rating)
        return result.single()[0]
    
    # `Review` Node
    def create_review(self, review_id, text):
        with self.driver.session() as session:
            review = session.write_transaction(self._create_review, review_id, text)
            print(review)
    
    @staticmethod
    def _create_review(tx, review_id, text):
        result = tx.run("CREATE (rev:Review) "
                        "SET rev.review_id = $review_id, rev.text = $text "
                        "RETURN rev.review_id + ', from node ' + id(rev)", review_id=review_id, text=text)
        return result.single()[0]
    
    # `User` Node
    def create_user(self, user_id, name, review_count):
        with self.driver.session() as session:
            user = session.write_transaction(self._create_user, user_id, name, review_count)
            print(user)
    
    @staticmethod
    def _create_user(tx, user_id, name, review_count):
        result = tx.run("CREATE (user:User) "
                        "SET user.user_id = $user_id, user.name = $name, "
                        "user.review_count = $review_count "
                        "RETURN user.user_id + ', from node ' + id(user)", user_id=user_id, name=name, 
                        review_count=review_count)
        return result.single()[0]
    
    # `Menu` Node
    def create_menu(self, menu_id, name):
        with self.driver.session() as session:
            menu = session.write_transaction(self._create_menu, menu_id, name)
            print(menu)
    
    @staticmethod
    def _create_menu(tx, menu_id, name):
        result = tx.run("MERGE (menu:Menu {menu_id: $menu_id, name: $name}) "
                        "RETURN menu.menu_id + ', from node ' + id(menu)", menu_id=menu_id, name=name)
        return result.single()[0]
    
    # `Aspect` Node
    def create_aspect(self, aspect_id, name):
        with self.driver.session() as session:
            aspect = session.write_transaction(self._create_aspect, aspect_id, name)
            print(aspect)
    
    @staticmethod
    def _create_aspect(tx, aspect_id, name):
        result = tx.run("MERGE (aspect:Aspect {aspect_id: $aspect_id, name: $name}) "
                        "RETURN aspect.aspect_id + ', from node ' + id(aspect)", aspect_id=aspect_id, name=name)
        return result.single()[0]
    
    
    # `City` Node
    def create_city(self, city_id, name):
        with self.driver.session() as session:
            city = session.write_transaction(self._create_city, city_id, name)
            print(city)
    
    @staticmethod
    def _create_city(tx, city_id, name):
        result = tx.run("MERGE (city:City {city_id: $city_id, name: $name}) "
                        "RETURN city.city_id + ', from node ' + id(city)", city_id=city_id, name=name)
        return result.single()[0]
    
    # `State` Node
    def create_state(self, state_id, name):
        with self.driver.session() as session:
            state = session.write_transaction(self._create_state, state_id, name)
            print(state)
    
    @staticmethod
    def _create_state(tx, state_id, name):
        result = tx.run("MERGE (state:State {state_id: $state_id, name: $name}) "
                        "RETURN state.state_id + ', from node ' + id(state)", state_id=state_id, name=name)
        return result.single()[0]
    
    # `Country` Node
    def create_country(self, country_id, name):
        with self.driver.session() as session:
            country = session.write_transaction(self._create_country, country_id, name)
            print(country)
    
    @staticmethod
    def _create_country(tx, country_id, name):
        result = tx.run("MERGE (country:Country {country_id: $country_id, name: $name}) "
                        "RETURN country.country_id + ', from node ' + id(country)", country_id=country_id, 
                        name=name)
        return result.single()[0]
    
    
    ######################################### Creating Relations ############################################
    
    # (User, User): HAS_FRIEND
    def create_user_has_friend_relation(self, user_id, friend_id):
        with self.driver.session() as session:
            relation = session.write_transaction(self._create_user_has_friend_relation, user_id, friend_id)
            print(relation)
    
    @staticmethod
    def _create_user_has_friend_relation(tx, user_id, friend_id):
        result = tx.run("MATCH (user:User {user_id: $user_id}), "
                        "(friend:User {user_id: $friend_id}) "
                        "MERGE (user)-[r:HAS_FRIEND]->(friend) "
                        "RETURN user.name, type(r), friend.name", user_id=user_id, friend_id=friend_id)
        return result.single()[0]
    
    # (Restaurant, Review): HAS_REVIEW
    def create_restaurant_has_review_relation(self, rest_id, review_id):
        with self.driver.session() as session:
            relation = session.write_transaction(self._create_restaurant_has_review_relation, rest_id, review_id)
            print(relation)
    
    @staticmethod
    def _create_restaurant_has_review_relation(tx, rest_id, review_id):
        result = tx.run("MATCH (rest:Restaurant {rest_id: $rest_id}), "
                        "(rev:Review {review_id: $review_id}) "
                        "MERGE (rest)-[r:HAS_REVIEW]->(rev) "
                        "RETURN rest.name, type(r), rev.id", rest_id=rest_id, review_id=review_id)
        return result.single()[0]
    
    # (User, Review): WROTE
    def create_user_wrote_review_relation(self, user_id, review_id, date):
        with self.driver.session() as session:
            relation = session.write_transaction(self._create_user_wrote_review_relation, user_id, review_id, date)
            print(relation)
    
    @staticmethod
    def _create_user_wrote_review_relation(tx, user_id, review_id, date):
        result = tx.run("MATCH (user:User {user_id: $user_id}), "
                        "(rev:Review {review_id: $review_id}) "
                        "MERGE (user)-[r:WROTE {date: $date}]->(rev) "
                        "RETURN user.name, type(r), rev.id", user_id=user_id, review_id=review_id, date=date)
        return result.single()[0]
    
    # (User, Restaurant): VISIT
    def create_user_visit_restaurant_relation(self, user_id, rest_id, date):
        with self.driver.session() as session:
            relation = session.write_transaction(self._create_user_visit_restaurant_relation, user_id, rest_id, 
                                                 date)
            print(relation)
    
    @staticmethod
    def _create_user_visit_restaurant_relation(tx, user_id, rest_id, date):
        result = tx.run("MATCH (user:User {user_id: $user_id}), "
                        "(rest:Restaurant {rest_id: $rest_id}) "
                        "MERGE (user)-[r:VISIT {date: $date}]->(rest) "
                        "RETURN user.name, type(r), rest.name", user_id=user_id, rest_id=rest_id, date=date)
        return result.single()[0]
    
    # (User, Restaurant): RATE
    def create_user_rate_restaurant_relation(self, user_id, rest_id, star):
        with self.driver.session() as session:
            relation = session.write_transaction(self._create_user_rate_restaurant_relation, user_id, rest_id, 
                                                 star)
            print(relation)
    
    @staticmethod
    def _create_user_rate_restaurant_relation(tx, user_id, rest_id, star):
        result = tx.run("MATCH (user:User {user_id: $user_id}), "
                        "(rest:Restaurant {rest_id: $rest_id}) "
                        "MERGE (user)-[r:RATE {star: $star}]->(rest) "
                        "RETURN user.name, type(r), rest.name", user_id=user_id, rest_id=rest_id, star=star)
        return result.single()[0]
    
    # (Restaurant, City): IN_CITY
    def create_restaurant_city_relation(self, rest_id, city_id):
        with self.driver.session() as session:
            relation = session.write_transaction(self._create_restaurant_city_relation, rest_id, city_id)
            print(relation)
    
    @staticmethod
    def _create_restaurant_city_relation(tx, rest_id, city_id):
        result = tx.run("MATCH (rest:Restaurant {rest_id: $rest_id}), "
                        "(city:City {city_id: $city_id}) "
                        "MERGE (rest)-[r:IN_CITY]->(city) "
                        "RETURN rest.name, type(r), city.name", rest_id=rest_id, city_id=city_id)
        return result.single()[0]
    
    # (City, State): IN_STATE
    def create_city_state_relation(self, city_id, state_id):
        with self.driver.session() as session:
            relation = session.write_transaction(self._create_city_state_relation, city_id, state_id)
            print(relation)
    
    @staticmethod
    def _create_city_state_relation(tx, city_id, state_id):
        result = tx.run("MATCH (city:City {city_id: $city_id}), "
                        "(state:State {state_id: $state_id}) "
                        "MERGE (city)-[r:IN_STATE]->(state) "
                        "RETURN city.name, type(r), state.name", city_id=city_id, state_id=state_id)
        return result.single()[0]
    
    # (State, Country): IN_COUNTRY
    def create_state_country_relation(self, state_id, country_id):
        with self.driver.session() as session:
            relation = session.write_transaction(self._create_state_country_relation, state_id, country_id)
            print(relation)
    
    @staticmethod
    def _create_state_country_relation(tx, state_id, country_id):
        result = tx.run("MATCH (state:State {state_id: $state_id}), "
                        "(country:Country {country_id: $country_id}) "
                        "MERGE (state)-[r:IN_COUNTRY]->(country) "
                        "RETURN state.name, type(r), country.name", state_id=state_id, country_id=country_id)
        return result.single()[0]
    
    

# if __name__ == "__main__":
#     greeter = GraphDB("bolt://localhost:7687", "neo4j", "erclab")
#     greeter.print_greeting("hello, world")
#     greeter.close()

# %%
###############################################################################################################
# Making tables in the Graph database from Yelp structured json dataset                                       #
#                                                                                                             #
# DB Schema is defined as follows:                                                                            #
#                                                                                                             #
# ##################  ##################  ############  ############  ##########  ###########  #############  #
# # `Restaurant`   #  # `User`         #  # `Aspect` #  # `Review` #  # `City` #  # `State` #  # `Country` #  #
# ##################  ##################  ############  ############  ##########  ###########  #############  #
# # - ID           #  # - ID           #  # - ID     #  # - ID     #  # - ID   #  # - ID    #  # - ID      #  #
# # - name         #  # - name         #  # - name   #  # - text   #  # - name #  # - name  #  # - name    #  #
# # - address      #  # - review_count #  ############  ############  ##########  ###########  #############  #
# # - postal_code  #  ##################                                                                      #
# # - rating       #                                                                                          #
# ##################                                                                                          #
#                                                                                                             #
###############################################################################################################

#################################################
#                                               #
# make triples from yelp structured json data   #
#                                               #
# User       -> visit(date) -> Review           #
# User       -> wrote(date) -> Review           #
# User       -> rate(star)  -> Restaurant       #
# User       -> has_friend  -> User             #
# Restaurant -> has_review  -> Review           #
# Restaurant -> has         -> Attribute/Aspect #
# Restaurant -> in_city     -> City             #
# City       -> in_state    -> State            #
# State      -> in_country  -> Country          #
#                                               #
#################################################

graph = GraphDB("bolt://localhost:7687", "neo4j", "erclab")

# Inserting users
users = restaurant_data['users']

print("inserting users in DB")
print("Total users: "+str(len(users)))
for user in users:
    graph.create_user(user["user_id"], user["name"], user["review_count"])
    
for user in users:
    friends = user['friends']
    
    if len(friends) == 0:
        continue
    
    for friend in friends:
        graph.create_user_has_friend_relation(user["user_id"], friend)
    
    
# Inserting restaurants
restaurants = restaurant_data['restaurants']
print("inserting restaurants in DB")
print("Total restaurants: "+str(len(restaurants)))
i = 0
for restaurant in restaurants:
#     graph.run("MERGE (rest:Restaurnat) SET rest.name = 'Alice'").stats()
    graph.create_restaurant(restaurant["rest_id"], restaurant["name"], restaurant["address"],
                                restaurant["postal_code"], restaurant["rating"])
    
    # Inserting reviews
    reviews = restaurant['reviews']
    
    print("["+str(i)+"] Inserting reviews for restaurant "+restaurant["rest_id"]+" - "+restaurant["name"]+"in DB")
    print("Total reviews: "+str(len(reviews)))
    for review in reviews:
        graph.create_review(review["review_id"], review["text"])
        
        graph.create_restaurant_has_review_relation(restaurant["rest_id"], review["review_id"])
        graph.create_user_wrote_review_relation(review["user_id"], review["review_id"], review["date"])
        graph.create_user_visit_restaurant_relation(review["user_id"], restaurant["rest_id"], review["date"])
        graph.create_user_rate_restaurant_relation(review["user_id"], restaurant["rest_id"], review["rating"])
        
    # Inserting city, state, country with relationships
    city, state, country = restaurant["city"], restaurant["state"], restaurant["country"]
    unique_country = "_".join(cc for cc in country.split())
    unique_state = f'{state}-{unique_country}'
    unique_city = f'{city}-{state}-{unique_country}'
    
    print("inserting city, state, country for restaurant "+restaurant["rest_id"]+" - "+restaurant["name"]+"in DB")
    graph.create_city(unique_city, city)
    graph.create_state(unique_state, state)
    graph.create_country(unique_country, country)
    
    graph.create_restaurant_city_relation(restaurant["rest_id"], unique_city)
    graph.create_city_state_relation(unique_city, unique_state)
    graph.create_state_country_relation(unique_state, unique_country)
    
    i += 1

graph.close()

# %%
import glob
import argparse
import logging
import pickle
import re
import json
import csv
from pprint import pprint

import pandas as pd

import spacy
from spacy import displacy
from spacy.matcher import Matcher
from spacy.util import filter_spans
from openie import StanfordOpenIE
from extract_entity import use_nltk_ner, use_spacy_ner, use_stanford_ner, use_allen_ner
from extract_relation import AllanRE
from resolve_coreference import AllenCR, StanfordCR, SpacyCR
from utils.spell_check import levenshtein_ratio_and_distance


from IPython.core.display import display, HTML
from libs.gpr_pub import visualization

# %%
# Initialize paths

output_path = "./data/output/"
ner_pickles_op = output_path + "ner/"
cr_pickles_op = output_path + "cr/"

''' read restaurant knowledgebase data '''
knowledge_base_entities = r"data/kb/entities/"
kb_restaurant_file = knowledge_base_entities + "restaurant.csv"
kb_menu_file = knowledge_base_entities + "menu.csv"
menu_extracted_file = knowledge_base_entities + "menu_extracted.csv"
kb_general_file = knowledge_base_entities + "general.csv"
kb_restaurant_aspects_file = knowledge_base_entities + "restaurant_aspects.csv"
kb_menu_aspects_file = knowledge_base_entities + "menu_attrs.csv"

entity_headers = ['Name', 'Label']

''' make dataframes for kb '''
kb_restaurant_df = pd.read_csv(kb_restaurant_file, header=0, names=entity_headers)
kb_menu_df = pd.read_csv(kb_menu_file, header=0, names=entity_headers)
# kb_general_df = pd.read_csv(kb_general_file, header=0, names=['Name', 'Label'])
kb_restaurant_aspects_df = pd.read_csv(kb_restaurant_aspects_file, header=0, names=entity_headers)
kb_menu_aspects_df = pd.read_csv(kb_menu_aspects_file, header=0, names=entity_headers)
print(kb_restaurant_df)
# Out:
#                       Name       Label
# 0  Silver spoon Restaurant  RESTAURANT
# 1             Bombay Grill  RESTAURANT

# %%
# credit: https://github.com/wang-h/bert-relation-classification/blob/master/utils.py
def clean_str(text):
    # Clean the text
    text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=<>]", " ", text)
    text = re.sub(r"[0-9]", " ", text)
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"that's", "that is ", text)
    text = re.sub(r"there's", "there is ", text)
    text = re.sub(r"it's", "it is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "can not ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " ", text)
#     text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)
    return text

def replace_subject_entity(text, entity):
    text = re.sub(r"\bI\b|\bi\b|\bWe\b|\bwe\b", entity, text)
    return text

# Clean reviews text
def clean_reviews(restaurants_data, save_clean_data=False):    
    rest_obj = dict()
    restaurants = restaurants_data
    for restaurant in restaurants:
        for review in restaurant['reviews']:
            review["text"] = clean_str(review["text"])
            review["text"] = replace_subject_entity(review["text"], review["name"])
    
    if save_clean_data:
        rest_obj['restaurants'] = restaurants
        with open('data/input/cleaned_reviews.json', 'w') as outfile:
            json.dump(rest_obj, outfile)
        
    
def split_sentence(text):
    '''
    splits review into a list of sentences using spacy's sentence parser
    '''
    nlp = spacy.load('en_core_web_sm')
    review = nlp(text)
    bag_sentence = []
    start = 0
    for token in review:
        if token.sent_start:
            bag_sentence.append(review[start:(token.i - 1)])
            start = token.i
        if token.i == len(review) - 1:
            bag_sentence.append(review[start:(token.i + 1)])
    return bag_sentence


def triple_pruning(triples, ner_dict):
    entity_set = set(ner_dict.keys())
    final_triples = []

    for row, col in triples.iterrows():
        col['subject'] = col['subject'].strip()

        # check if Named Entity in subject sentence fragment
        # found_entity = False
        # for named_entity in entity_set:
        #     if named_entity in col['subject']:
        #         col['subject'] = named_entity
        #         found_entity = True
        #
        # if found_entity:
        final_triples.append(('Node', col['subject'], col['relation'], 'Node', col['object']))

    triple_df = pd.DataFrame(final_triples, columns=['Type1', 'Entity1', 'Relationship', 'Type2', 'Entity2']).drop_duplicates()
    return triple_df

# %%
SUBJECTS = ["nsubj", "nsubjpass", "csubj", "csubjpass", "agent", "expl"]
OBJECTS = ["dobj", "dative", "attr", "oprd"]
ATTRS = ["acomp"]
POSS_NOUN = ["NOUN", "PROPN", "X"]


def get_compounds(tokens):
    compounds = []
    lefts = list(tokens.lefts)
    compounds.extend([tok for tok in lefts if tok.dep_ == 'compound'])
    return compounds


def get_subject_compound(v):
    subs = []
    compounds = []
    for tok in v.lefts:
        if tok.dep_ in SUBJECTS and tok.pos_ != "DET":
            compounds = get_compounds(tok)
            compounds.extend([tok])
    if compounds:
        subs.extend(compounds)
    return subs


def get_object_compound(v):
    objs = []
    compounds = []
    for tok in v.rights:
        if tok.dep_ in OBJECTS:
            compounds = get_compounds(tok)
            compounds.extend([tok])
    if compounds:
        objs.extend(compounds)
    return objs


def get_attribute_compound(av):
    objs = []
    compounds = []
    for tok in av.rights:
        if tok.dep_ in ATTRS:
            compounds = get_compounds(tok)
            compounds.extend([tok])
    if compounds:
        objs.extend(compounds)
    return objs


def get_prep_object_compound(p):
    p_objs = []
    compounds = []
    for tok in p.rights:
        if tok.dep_ == 'pobj':
            compounds = get_compounds(tok)
            compounds.extend([tok])
    if compounds:
        p_objs.extend(compounds)
    return p_objs


def get_prep(p):
    prep = False
    for tok in p.rights:
        if tok.dep_ == 'prep':
            prep = tok
    return prep


def get_lexical_triplets_pairs(text_doc, verbose=False):

    nlp = spacy.load('en_core_web_sm')
    doc = nlp(text_doc)

#     print([(ent.text, ent.label_) for ent in doc.ents])

    triplets = []

    verbs = [tok for tok in doc if tok.pos_ == "VERB"]

    # getting sub, verb, obj triples
    # Angela, visit, silver spoon restaurant
    for v in verbs:
        subs = get_subject_compound(v)
        objs = get_object_compound(v)

        if subs and objs:
            triplets.append([' '.join(str(i) for i in subs), v, ' '.join(str(i) for i in objs)])

    # getting sub, verb_prep, p_obj triples
    # Angela, visit_with, Angela's friends
    for v in verbs:
        subs = get_subject_compound(v)
        prep = get_prep(v)

        p_objs = False
        if prep:
            p_objs = get_prep_object_compound(prep)

        if subs and p_objs:
            triplets.append([' '.join(str(i) for i in subs), str(v)+'_'+str(prep), ' '.join(str(i) for i in p_objs)])

    # getting sub, possession, obj triples
    # Silver spoon restaurant, has, Chicken biryani
    subs, objs = (False, False)
    poss_nouns = [tok for tok in doc if tok.pos_ in POSS_NOUN]
    for n in poss_nouns:
        children = list(n.children)
        for child in children:
            if child.dep_ == 'poss' and child.pos_ in POSS_NOUN:
                compounds = get_compounds(child)
                compounds.extend([child])
                subs = compounds

                compounds = get_compounds(n)
                compounds.extend([n])
                objs = compounds

                if subs and objs:
                    triplets.append([' '.join(str(i) for i in subs), 'has', ' '.join(str(i) for i in objs)])

    # getting sub, aux, complementary object triples
    # food, are, good
    subs, objs = (False, False)
    aux_verbs = [tok for tok in doc if tok.pos_ == "AUX"]
    for av in aux_verbs:
        subs = get_subject_compound(av)
        objs = get_attribute_compound(av)

        if subs and objs:
            triplets.append([' '.join(str(i) for i in subs), av, ' '.join(str(i) for i in objs)])

#     pprint(triplets)
    return triplets

# %%
# Clean reviews text
clean_reviews(restaurant_data['restaurants'], save_clean_data=True)

# %%
from transformers import BertModel, BertForTokenClassification, BertTokenizer
import torch
import torch.nn as nn

class MenuNER:
    
    def __init__(self):
        self.model = BertForTokenClassification.from_pretrained(
            "/home/muzamil/Projects/Python/ML/NLP/NER/BERT-NER/out_ner/")
        self.tokenizer = BertTokenizer.from_pretrained(
            "/home/muzamil/Projects/Python/ML/NLP/NER/MenuNER/model/FoodieBERT/cased_L-12_H-768_A-12")
        
    def extract_menu_ner(self, restaurants, write_results=False):

        menu_ner = dict()
        for restaurant in restaurants['restaurants']:
            for review in restaurant['reviews']:

                sequence = review['text']
                predict = self._extract_menu_ner(self.model, self.tokenizer, sequence)
                menu_ner.update(predict)
                print(predict)

        print(menu_ner)
        if write_results:
               # opening the csv file in 'w' mode
            open_menu_extracted_file = open(menu_extracted_file, 'w')
            writer = csv.DictWriter(open_menu_extracted_file, fieldnames=entity_headers)

            writer.writeheader()
            for key, value in menu_ner.items():
                writer.writerow({entity_headers[0]: key,
                                 entity_headers[1]: value})
        
    
    @staticmethod
    def _extract_menu_ner(model, tokenizer, sequence):

        label_list = [
            "O",       # Outside of a named entity
            "B-MENU",  # Beginning of a menu entity
            "I-MENU",  # menu entity
        ]
        
        # Bit of a hack to get the tokens with the special tokens
        tokens = tokenizer.tokenize(tokenizer.decode(tokenizer.encode(sequence, max_length=512, truncation=True)))
        inputs = tokenizer.encode(sequence, return_tensors="pt")

        predict = {}
        print(inputs.size()[1])
        if inputs.size()[1] > 512:
            return predict

        outputs = model(inputs)[0]
        predictions = torch.argmax(outputs, dim=2)

        full_token = ''
        
        for token, prediction in zip(tokens, predictions[0].tolist()):
            if token != '[CLS]' and token != '[SEP]':
                if prediction > 3:
                    continue
                if label_list[prediction-1] in ["B-MENU", "I-MENU"]:
                    if token.startswith('##'):
                        full_token = full_token + token.replace("##", "")
                    else:
                        if full_token:
                            full_token = full_token +" "+token
                        else:
                            full_token = token
                elif full_token:
                    if token.startswith('##'):
                        full_token = full_token + token.replace("##", "")
                    else:
                        predict[full_token] = "MENU"
                        full_token = ''

        # Make first letter capitan and all small case for MenuNER
        predict = dict((key.title(), value) for (key, value) in predict.items())
        return predict

# %%
# Load MenuNER model to extract Food entities

menu_ner = MenuNER()
# menu_ner.extract_menu_ner(restaurant_cleaned_reviews, write_results=True)
menu_ner.extract_menu_ner(restaurant_data, write_results=True)
# Out:
# 86
# {'Dosa': 'MENU'}
# 26
# {}
# 362
# {'Guthi Vonkaya Kura Peshwari Chana': 'MENU', 'Rice': 'MENU', 'Raita': 'MENU', 'Curries': 'MENU', 'Kura': 'MENU', 'Stuffed Indian Eggplant': 'MENU', 'Chana': 'MENU', 'Kerala Fish Curry': 'MENU'}
# 249
# {'Chicken Tikka Masala': 'MENU', 'Okra Curry': 'MENU', 'Dal': 'MENU', 'Naan': 'MENU', 'Rice': 'MENU', 'Curry': 'MENU'}
# 54
# {'Naan': 'MENU'}
# 291
# {'Crispy Pakoras': 'MENU', 'Veg Biriyani': 'MENU', 'Mushroom Peas Masala Curry': 'MENU', 'Sambar': 'MENU', 'Dosas': 'MENU', 'Mirch Curry': 'MENU'}
# 74
# {'Chicken 65': 'MENU', 'Andhra Chicken Curry': 'MENU', 'Spice South Chicken Curry': 'MENU'}
# 67
# {'Sambar': 'MENU', 'Dosas': 'MENU'}
# 102
# {'Biriyani': 'MENU', 'Rice': 'MENU', 'Chicken': 'MENU'}
# 122
# {}
# 37
# {}
# 68
# {}
# 122
# {'Chicken Tikka Masala': 'MENU', 'Vegetable Curry': 'MENU'}
# 206
# {'Chicken Tikka Masala': 'MENU', 'Biryani': 'MENU', 'Vegetables': 'MENU', 'Chicken': 'MENU', 'Lamb': 'MENU', 'Goat': 'MENU'}
# 51
# {'Tikki Marsala': 'MENU', 'Naan Bread': 'MENU'}
# 59
# {}
# 84
# {'Masala Dosa': 'MENU', 'Chicken Chettinad': 'MENU', 'Panir Butter Masala': 'MENU', 'Garlic Nan': 'MENU'}
# 75
# {'Naan': 'MENU'}
# 62
# {}
# 248
# {'Papadums': 'MENU', 'Chutney': 'MENU', 'Lamb': 'MENU', 'Indian Beers': 'MENU'}
# 203
# {'Naan': 'MENU', 'Goat Curry': 'MENU', 'Chicken Tandoori': 'MENU', 'Beef Vindaloo': 'MENU', 'Palak Paneer': 'MENU', 'Eer': 'MENU', 'Vegetable Pakoras': 'MENU', 'Butter Chicken': 'MENU'}
# 142
# {'Butter Chicken': 'MENU', 'Parathas': 'MENU', 'Buttery Parathas': 'MENU'}
# 149
# {'Kabab': 'MENU', 'Mutton Karhai': 'MENU', 'Mutton': 'MENU', 'Chicken Tikka': 'MENU', 'Nan': 'MENU', 'Dal': 'MENU'}
# 41
# {'Roti': 'MENU'}
# 112
# {'Naans': 'MENU', 'Mushroom Masala': 'MENU', 'Mushrooms': 'MENU', 'Butter & Tandoori Chicken': 'MENU'}
# 158
# {'Vegetables': 'MENU', 'Seafood': 'MENU', 'Fish': 'MENU', 'Pani Puri': 'MENU', 'Pani Puris': 'MENU', 'Salads': 'MENU'}
# 121
# Token indices sequence length is longer than the specified maximum sequence length for this model (1140 > 512). Running this sequence through the model will result in indexing errors
# {'Chicken Biryani': 'MENU', 'Chicken Tikka': 'MENU', 'Ras Malai': 'MENU', 'Biryani': 'MENU'}
# 86
# {}
# 25
# {'Butter Chicken': 'MENU'}
# 1140
# {}
# 37
# {}
# 169
# {'Aloo Gobi': 'MENU', 'Paneer Makhani': 'MENU'}
# 79
# {}
# 202
# {'Pickles': 'MENU', 'Gulab Jamon': 'MENU', 'Makhni Dahl': 'MENU', 'Pakora': 'MENU', 'Butter Chicken': 'MENU', 'Naan': 'MENU'}
# 39
# {}
# 136
# {}
# 37
# {}
# 62
# {'Butter Chicken': 'MENU'}
# 468
# {'Butter Chicken': 'MENU', 'Chicken': 'MENU', 'Tandoori Chicken': 'MENU', 'Pasta': 'MENU', 'Aloo Gobi': 'MENU', 'Potato / Cauliflower Curry': 'MENU', 'Naan Bread': 'MENU', 'Perience': 'MENU'}
# 91
# {}
# 381
# {'Butter Chicken': 'MENU', 'Butter Chicken Sauce': 'MENU', 'Naan': 'MENU', 'Ice Cream': 'MENU', 'Rice Pudding': 'MENU', 'Gulabjam': 'MENU'}
# 291
# {'Tandoori Chicken': 'MENU', 'Butter Chicken': 'MENU', 'Rice': 'MENU', 'Pakoras': 'MENU', 'Chicken Breast': 'MENU', 'Naan': 'MENU'}
# 466
# {'Chili Chicken': 'MENU', 'Chicken Curry': 'MENU', 'Chicken Biryani Combo': 'MENU'}
# 50
# {'Veggie Samosas': 'MENU', 'Spicy Chicken': 'MENU', 'Chicken Birani': 'MENU'}
# 110
# {'Chicken Samosa': 'MENU', 'Kothu Roti': 'MENU', 'Coconut Roti': 'MENU', 'Rice Noodle': 'MENU'}
# 17
# {'Yellow Thin Noodles': 'MENU'}
# 50
# {'Snacks': 'MENU'}
# 122
# {'Rice': 'MENU'}
# 71
# {'Samosas': 'MENU', 'Masala Dosa': 'MENU'}
# 76
# {'Samosas': 'MENU'}
# 35
# {'Samosas': 'MENU'}
# 34
# {'Rolls': 'MENU', 'Biriyani': 'MENU'}
# 76
# {}
# 64
# {'Dosa': 'MENU', 'Idllis': 'MENU'}
# 77
# {'Noodles': 'MENU', 'Rice': 'MENU', 'Rolls': 'MENU', 'Samosas': 'MENU', 'Rotis': 'MENU'}
# 200
# {'Samosas': 'MENU', 'Hot Rolls': 'MENU'}
# 43
# {'Samosa': 'MENU', 'Biriyani': 'MENU', 'Tomato Rice': 'MENU', 'Chicken': 'MENU'}
# 228
# {'Crispy Masala Fried Corn': 'MENU', 'Boiled Egg': 'MENU', 'Sauce': 'MENU', 'Fruit Custard': 'MENU', 'Raita': 'MENU', 'Yogurt Sauce': 'MENU'}
# 113
# {'Gobi': 'MENU', 'Chana Masala': 'MENU', 'Naan': 'MENU', 'Sauces': 'MENU'}
# 145
# {'Fried Cauliflower': 'MENU', 'Butter Chicken': 'MENU', 'Eer': 'MENU'}
# 99
# {}
# 158
# {'Malai Kofta': 'MENU', 'Saag Paneer': 'MENU', 'Plain Rice': 'MENU', 'Naan': 'MENU', 'Saag': 'MENU', 'Chutney': 'MENU', 'Rice': 'MENU'}
# 103
# {'Dosa': 'MENU', 'Dosas': 'MENU', 'Chai': 'MENU', 'Dosa Dinner': 'MENU'}
# 187
# {'Dosa': 'MENU', 'Dosas': 'MENU', 'Butter Masala': 'MENU', 'Chana Masala': 'MENU'}
# 87
# {'Shrimp Curry': 'MENU'}
# 52
# {}
# 52
# {}
# 181
# {'Palak Paneer': 'MENU'}
# 29
# {}
# 133
# {'Tandoor Chicken': 'MENU'}
# 53
# {}
# 49
# {'Mysore Masala Dosa': 'MENU', 'Chana Batura': 'MENU', 'Batura': 'MENU'}
# 37
# {}
# 402
# {'Gobi 65': 'MENU', 'Fried Cauliflower': 'MENU', 'Gobi': 'MENU', 'Paneer': 'MENU', 'Indian Cheese': 'MENU', 'Curry': 'MENU', 'Ravaa Dosa': 'MENU', 'Chutney': 'MENU', 'Lentil Soup': 'MENU', 'Dosa': 'MENU', 'Dosas': 'MENU', 'Cheese Bread': 'MENU', 'Beer': 'MENU', 'Wine': 'MENU'}
# 422
# {'Sushi': 'MENU', 'Chicken': 'MENU', 'Chicken Masala And Curry': 'MENU', 'Eggplant': 'MENU', 'Charts': 'MENU', 'Bread Pudding': 'MENU'}
# 84
# {'Dosa': 'MENU', 'Dosas': 'MENU', 'Egg Bhurji': 'MENU', 'Butter Chicken': 'MENU', 'Lamb': 'MENU', 'Egg Dosas': 'MENU'}
# 34
# {'Biryani': 'MENU', 'Chicken Tikka Masala': 'MENU'}
# 310
# {'Dosas': 'MENU', 'Mimosas': 'MENU', 'Dosa': 'MENU'}
# 136
# {'Dosa': 'MENU', 'Biryani': 'MENU', 'Uthappam': 'MENU', 'Chole Batura': 'MENU', 'Idli': 'MENU', 'Sambar': 'MENU', 'Veg Dosas': 'MENU', 'Masala Dosa Guntur Masala Dosa Mysore Masala Dosa Ghee Dosa Plain Dosa Spring Noodles Dosa Non - Veg Dosas': 'MENU', 'Omelet Dosa Kodi Vepudu Dosa Lamb Sukka Dosa Kids Dosas': 'MENU'}
# 258
# {'Dosa': 'MENU', 'Dosas': 'MENU', 'Butter Chicken Dosa': 'MENU', 'Chai Tea': 'MENU'}
# 102
# {'Dalpuri': 'MENU', 'Aloo Chana': 'MENU', 'Tomatoes Choka': 'MENU', 'Fried Fish Sandwich': 'MENU', 'Doubles': 'MENU'}
# 70
# {'Doubles': 'MENU'}
# 168
# {'Roti': 'MENU', 'Doubles': 'MENU'}
# 34
# {'Doubles': 'MENU'}
# 44
# {'Roti': 'MENU'}
# 48
# {'Boneless Goat': 'MENU'}
# 136
# {'Doubles': 'MENU', 'Curry': 'MENU'}
# 264
# {'Doubles': 'MENU', 'Aloo Pie': 'MENU', 'Pholourie': 'MENU', 'Boneless Goat Roti': 'MENU', 'Currants Roll': 'MENU', 'Kurma': 'MENU', 'Curry Goat': 'MENU', 'Goat': 'MENU', 'Roti': 'MENU'}
# 24
# {}
# 54
# {}
# 34
# {'Roti': 'MENU', 'Goat Curry Roti': 'MENU'}
# 44
# {'Doubles': 'MENU', 'Goat Roti': 'MENU', 'Paratha': 'MENU', 'Roti': 'MENU'}
# 159
# {'Sauce': 'MENU', 'Doubles': 'MENU', 'Sauces': 'MENU'}
# 294
# {'Roti': 'MENU', 'Doubles': 'MENU', 'Chicken Doubles': 'MENU', 'Chicken Roti': 'MENU', 'Lamb': 'MENU'}
# 136
# {'Roti': 'MENU', 'Doubles': 'MENU', 'Chutney': 'MENU', 'Pepper Sauce': 'MENU'}
# 95
# {'Roti': 'MENU', 'Okra': 'MENU', 'Chicken Roti': 'MENU', 'Goat Roti': 'MENU'}
# 138
# {'Goat Dhalpourie Roti': 'MENU', 'Goat': 'MENU', 'Roti': 'MENU'}
# 196
# {'Lena': 'MENU', 'Oti': 'MENU', 'Dhal Roti': 'MENU', 'Channa': 'MENU', 'Aloo': 'MENU', 'Hot Sauce': 'MENU', 'Rotis': 'MENU', 'Squash': 'MENU', 'Jamaica Rotis': 'MENU', "Lena ' S Roti": 'MENU'}
# 111
# {'Doubles': 'MENU', 'Goat': 'MENU', 'Dhalpuri': 'MENU', 'Veggie Platter': 'MENU', 'Jackfruit': 'MENU', 'Mango': 'MENU', 'Callaloo': 'MENU', 'Chick Peas': 'MENU', 'Okra': 'MENU', 'Chutney': 'MENU', 'Hot Sauce': 'MENU'}
# 33
# {}
# 92
# {'Shrimp Pakoras': 'MENU', 'Chicken Tangra': 'MENU', 'Chicken Tikka Masala': 'MENU', 'Manchurian Seafood Rice': 'MENU', 'Seafood': 'MENU'}
# 121
# {'Chili Chicken': 'MENU', 'Tangra Villa Chicken': 'MENU', 'Crispy Ginger Beef': 'MENU'}
# 84
# {}
# 74
# {'Tangra Villa Chicken': 'MENU', 'Noodles': 'MENU', 'Fried Rice': 'MENU'}
# 139
# {'Spring Rolls': 'MENU', 'Spring Roll': 'MENU', 'Fried Rice': 'MENU', 'Noodles': 'MENU'}
# 128
# {'Pakora': 'MENU', 'Tangra Chicken': 'MENU', 'Chilli Chicken': 'MENU', 'Crispy Beef': 'MENU'}
# 53
# {'Chili Chicken': 'MENU', 'Crispy Ginger Beef': 'MENU', 'Beef': 'MENU'}
# 124
# {'General Tao Chicken': 'MENU', 'Rice': 'MENU', 'Singaporean Noodles': 'MENU', 'Curry': 'MENU'}
# 92
# {'Chilli Chicken': 'MENU'}
# 302
# {'Tangra': 'MENU', 'Chicken': 'MENU', 'Beef': 'MENU', 'Fish': 'MENU', 'Shrimp': 'MENU', 'Noodle': 'MENU', 'Rice': 'MENU', 'Vegetarian Dishes': 'MENU', 'Chili Dishes': 'MENU', 'Mango Dishes': 'MENU', 'Sauces': 'MENU', 'Stir': 'MENU', 'Fried Onions': 'MENU', 'Tangra - Villa Meat': 'MENU', 'Garlic And Soy Sauce': 'MENU'}
# 39
# {'Hot & Sour Soup': 'MENU', 'Tom Yum Soup': 'MENU'}
# 38
# {'Tangra Villa': 'MENU'}
# 94
# {'Crispy Ginger Beef': 'MENU', 'Tangra Villa': 'MENU', 'Seafood': 'MENU'}
# 73
# {'Schezwan Chicken': 'MENU', 'Manchurian Fried Rice': 'MENU', 'Fried Rice': 'MENU'}
# 107
# {'Hot And Sour Soup': 'MENU', 'Chicken Pakora': 'MENU', 'Fried Rice': 'MENU', 'Chicken': 'MENU', 'Beef': 'MENU'}
# 109
# {'Chili Chicken': 'MENU', 'Veggie Chow Mein': 'MENU', 'Fried Rice': 'MENU', 'Chow Mein': 'MENU'}
# 68
# {}
# 59
# {'Chili Paneer Schezwen': 'MENU', 'Rice': 'MENU', 'Hot Sour Soup': 'MENU'}
# 43
# {}
# 195
# {}
# 43
# {}
# 65
# {}
# 70
# {'Manchurian Chicken': 'MENU', 'Hakka Noodles': 'MENU', 'Tangra Villa': 'MENU'}
# 54
# {}
# 47
# {'Chili Chicken': 'MENU', 'Sauce': 'MENU', 'Spring Roll': 'MENU', 'Chicken': 'MENU'}
# 85
# {'Chili Chicken': 'MENU', 'Spring Roll': 'MENU'}
# 263
# {'Chili Chicken': 'MENU', 'Rice': 'MENU'}
# 185
# {'Chicken Pakoras': 'MENU', 'Singapore Noodles': 'MENU', 'Tangra Villa Chicken': 'MENU', 'Chicken': 'MENU', 'Pakora': 'MENU', 'Curry': 'MENU', 'Chili Chicken': 'MENU', 'Beef': 'MENU'}
# 52
# {'Chicken Pakoras': 'MENU', 'Fried Rice': 'MENU'}
# 32
# {}
# 71
# {'Goat Curry': 'MENU'}
# 85
# {'Pork Dish': 'MENU'}
# 350
# {'Mango Lassi': 'MENU', 'Lassi': 'MENU', 'Tandoori Chicken': 'MENU', 'Samosa': 'MENU'}
# 204
# {'Chicken Tikka Masala': 'MENU', 'Chicken': 'MENU', 'Mango Lassi': 'MENU'}
# 50
# {'Vege Biryani': 'MENU'}
# 336
# {'Shahi Paneer': 'MENU', 'Vegetable Korma': 'MENU', 'Bhindi Masala': 'MENU', 'Chicken': 'MENU', 'Lamb': 'MENU', 'Seafood': 'MENU', 'Beef': 'MENU', 'Pork': 'MENU', 'Naan': 'MENU', 'Mango Lassi': 'MENU', 'Curry': 'MENU'}
# 79
# {'Spicy Goat Curry': 'MENU', 'Rice With Peas': 'MENU'}
# 146
# {'Coconut Naan': 'MENU', 'Lamb Masala': 'MENU', 'Curry': 'MENU'}
# 106
# {'Tandoori Mixed Grill': 'MENU', 'Shrimp': 'MENU', 'Tender Chicken': 'MENU', 'Fish': 'MENU', 'Vegetables': 'MENU', 'Rice': 'MENU', 'Tikka Masala': 'MENU', 'Garlic Sauce': 'MENU'}
# 275
# {'Samosas': 'MENU', 'Naan': 'MENU', 'Chicken Tikka Masala': 'MENU', 'Curries': 'MENU', 'Mango Ice Cream': 'MENU'}
# 64
# {'Veggie Vindaloo': 'MENU', 'Chicken Tikka Masala': 'MENU', 'Aloo Gobi': 'MENU'}
# 123
# {'Curry': 'MENU'}
# 68
# {'Cheese Naan': 'MENU', 'Naan': 'MENU', 'Bread': 'MENU'}
# 36
# {}
# 152
# {'Chicken Tikka Masala': 'MENU'}
# 132
# {'Naan': 'MENU', 'Curry': 'MENU', 'Chicken Tikka Masala': 'MENU', 'Garlic Naan': 'MENU', 'Curry With Chicken': 'MENU'}
# 87
# {'Chicken Tikka Masala': 'MENU'}
# 97
# {}
# 70
# {'Dal Tadka': 'MENU', 'Paneer Tikka Masala': 'MENU', 'Chapati': 'MENU'}
# 30
# {}
# 85
# {}
# 246
# {'Eggplant': 'MENU', 'Tikki Masala': 'MENU', 'Regular Nan': 'MENU', 'Coconut Nan': 'MENU', 'Tandoori Chicken': 'MENU', 'Rice Pudding': 'MENU', 'Mango Lassi': 'MENU'}
# 201
# {'Naan': 'MENU', 'Chai': 'MENU'}
# 83
# {'Chicken Curry': 'MENU'}
# 60
# {}
# 21
# {}
# 52
# {'Naan': 'MENU', 'Cheese Naan': 'MENU'}
# 54
# {'Naan Bread': 'MENU'}
# 48
# {}
# 137
# {'Shrimp Curry': 'MENU', 'Tandoori Mixed Grill': 'MENU', 'Garlic Naan': 'MENU'}
# 85
# {'Shahi Paneer': 'MENU', 'Aloo Ghobi': 'MENU'}
# 344
# {'Papadam': 'MENU', 'Chutneys': 'MENU', 'Veggie Korma': 'MENU', 'Naan': 'MENU', 'Korma Sauce': 'MENU', 'Vegetarian Eggplant': 'MENU', 'Rice Pudding': 'MENU', 'Fried Cheese Balls': 'MENU'}
# 63
# {'Lamb Curry': 'MENU', 'Chutney': 'MENU'}
# 116
# {'Tandoori Roti': 'MENU'}
# 138
# {'Briyani': 'MENU', 'Ice Cream': 'MENU', 'Rice': 'MENU'}
# 134
# {'Tandoori Mixed Grill': 'MENU', 'Tandoori Chicken': 'MENU', 'Shrimp': 'MENU', 'Seekh Kabab': 'MENU'}
# 48
# {}
# 30
# {}
# 42
# {'Masala Curries': 'MENU', 'Naan': 'MENU'}
# 88
# {}
# 26
# {}
# 33
# {'Goat Meat Curry': 'MENU'}
# 158
# {'Lamb Shahi Korma': 'MENU', 'Plain Lassis': 'MENU', 'Naan': 'MENU'}
# 54
# {'Chicken Tikka Masala': 'MENU', 'Lamb Madras': 'MENU', 'Garlic Naan': 'MENU'}
# 41
# {}
# 220
# {'Naan': 'MENU', 'Chutney': 'MENU', 'Chicken Soup': 'MENU'}
# 104
# {'Breads': 'MENU'}
# 121
# {}
# 55
# {}
# 264
# {'Chicken': 'MENU', 'Goat': 'MENU', 'Bharta': 'MENU', 'Vegetable': 'MENU', 'Dal': 'MENU'}
# 23
# {}
# 62
# {'Rice': 'MENU', 'Lamb': 'MENU'}
# 197
# {'Chicken Tikka Masala': 'MENU', 'Sauce': 'MENU', 'Naan': 'MENU', 'Garlic Naan': 'MENU', 'Mango Lassi': 'MENU'}
# 60
# {'Curry': 'MENU'}
# 99
# {'Butter Chicken': 'MENU', 'Chicken Makhni': 'MENU', 'Garlic Naan': 'MENU', 'Roti': 'MENU', 'Chicken Curry': 'MENU', 'Naan': 'MENU'}
# 161
# {'Vegetables': 'MENU', 'Curry': 'MENU', 'Tandoori Mixed Grill': 'MENU', 'Papadams': 'MENU', 'Garlic Naan': 'MENU'}
# 59
# {'Rice': 'MENU', 'Sauce': 'MENU'}
# 186
# {'Coconut Naan': 'MENU', 'Shrimp Korma': 'MENU', 'Shrimp': 'MENU'}
# 85
# {'Garlic Naan': 'MENU'}
# 100
# {'Samosas': 'MENU', 'Chicken Tikka Masala': 'MENU', 'Butter Chicken': 'MENU', 'Tikka Masala': 'MENU', 'Mango Ice Cream': 'MENU', 'Ice Cream': 'MENU'}
# 30
# {}
# 143
# {'Lamb Samosas': 'MENU', 'Samosas': 'MENU', 'Lamb': 'MENU', 'Goat Curry': 'MENU', 'Shrimp Korma': 'MENU', 'Coconut Naan': 'MENU', 'Sauce': 'MENU', 'Spicy Sauce': 'MENU', 'Shrimp': 'MENU'}
# 258
# {'Samosas': 'MENU', 'Aloo Mutter': 'MENU', 'Goat Curry': 'MENU'}
# 37
# {}
# 127
# {'Chicken Shahkorma': 'MENU', 'Fried Paneer': 'MENU', 'Cheese Naan': 'MENU', 'Chicken': 'MENU', 'Sauce': 'MENU'}
# 171
# {'Tandoori Chicken': 'MENU', 'Tadka Daal': 'MENU', 'Mango Ice Cream': 'MENU', 'Lassi': 'MENU'}
# 124
# {'Vegetable Appetizer Platter': 'MENU'}
# 92
# {'Chicken Tikka Masala': 'MENU'}
# 82
# {'Pad Panang': 'MENU', 'Rice': 'MENU', 'Tom Yum Soup': 'MENU', 'Mushrooms': 'MENU'}
# 94
# {}
# 215
# {'Curry': 'MENU', 'Pork Curry': 'MENU', 'Chicken Masala': 'MENU', 'Spinach Naan': 'MENU', 'Mango Ice Cream': 'MENU', 'Beef Broccoli': 'MENU'}
# 21
# {}
# 147
# {'Curry': 'MENU'}
# 247
# {}
# 46
# {}
# 37
# {}
# 30
# {}
# 81
# {}
# 107
# {'Cheese Naan': 'MENU', 'Lamb Saag Curry': 'MENU'}
# 88
# {'Chicken Biryani': 'MENU', 'Mutter Paneer': 'MENU', 'Chicken Tikka Masa': 'MENU', 'Samosa': 'MENU', 'Pakora': 'MENU'}
# 87
# {}
# 81
# {}
# 41
# {'Naan': 'MENU', 'Chicken Kabob': 'MENU', 'Butter Chicken': 'MENU'}
# 89
# {'Chai': 'MENU'}
# 218
# {}
# 109
# {'Lamb And Goat Stew': 'MENU', 'Curry': 'MENU', 'Fried Naan Bread': 'MENU', 'Fish Pakora': 'MENU', 'Mango Ice Cream': 'MENU', 'Mango Lassi': 'MENU'}
# 88
# {'Naan': 'MENU', 'Lamb Masala': 'MENU'}
# 142
# {'Shabu Paneer': 'MENU', 'Goat Meat Curry': 'MENU'}
# 140
# {}
# 80
# {'Vegetable Appetizer': 'MENU'}
# 41
# {'Samosa': 'MENU', 'Pakora': 'MENU'}
# 92
# {'Tandoori Fish Tikka': 'MENU', 'Coconut Naan': 'MENU'}
# 247
# {'Sauce': 'MENU', 'Cheese Filled Naan': 'MENU', 'Chicken Tikka Masala': 'MENU', 'Rice': 'MENU', 'Sauces': 'MENU'}
# 220
# {'Fish Masala': 'MENU', 'Palak Paneer': 'MENU', 'Sweet Naan': 'MENU', 'Garlic Naan': 'MENU', 'Rice Pudding': 'MENU', 'Rice': 'MENU', 'Mango Lassi': 'MENU'}
# 141
# {'Tikka Masala': 'MENU', 'Chutneys': 'MENU', 'Rices': 'MENU', 'Naan': 'MENU', 'Sauces': 'MENU'}
# 357
# {'Curry': 'MENU', 'Chicken': 'MENU', 'Goat Curry': 'MENU', 'Cheese And Garlic Naan Bread': 'MENU', 'Chicken Curries': 'MENU', 'White Meat': 'MENU', 'Chicken Breast': 'MENU', 'Sauce': 'MENU', 'Rice': 'MENU', 'Chicken Breast Pieces': 'MENU'}
# 211
# {'Butter Chicken': 'MENU', 'Lamb Curry': 'MENU', 'Cheese Naan': 'MENU'}
# 83
# {'Spinach Naan': 'MENU', 'Mango Lassi': 'MENU'}
# 178
# {'Chicken': 'MENU', 'Lamb': 'MENU', 'Malai Kofta': 'MENU', 'Rice': 'MENU', 'Daal': 'MENU', 'Aloo Zucchini': 'MENU'}
# 83
# {'Mango Ice Cream': 'MENU'}
# 33
# {'Chicken Tikka Masala': 'MENU', 'Naan': 'MENU'}
# 169
# {'Vegetable Soup': 'MENU'}
# 115
# {'Coconut Naan Bread': 'MENU', 'Chai Tea': 'MENU', 'Chai': 'MENU'}
# 193
# {'Tikka Masala': 'MENU', 'Fish': 'MENU', 'White Meat Fish': 'MENU', 'Shahikorma Sauce': 'MENU', 'Naan Bread': 'MENU', 'Naan': 'MENU', 'Rice': 'MENU'}
# 268
# {'Naan': 'MENU', 'Rice': 'MENU', 'Goat': 'MENU', 'Vegetable Curry': 'MENU'}
# 382
# {'Mango Lassi': 'MENU', 'Mango Juice': 'MENU', 'Vegetable Platter': 'MENU', 'Paneer Pakora': 'MENU', 'Aloo Tikki': 'MENU', 'Chicken Tikka Masala': 'MENU', 'Shahi Paneer': 'MENU', 'Chicken Tikka': 'MENU', 'Garlic Naan': 'MENU', 'Coconut Naan': 'MENU', 'Bread': 'MENU', 'Sauces': 'MENU'}
# 243
# {}
# 71
# {}
# 248
# {'Chicken Tikka Masala': 'MENU', 'Vindaloo': 'MENU', 'Pakoora': 'MENU', 'Samosas': 'MENU', 'Fried Naan': 'MENU', 'Mushroom And Paneer Masala': 'MENU'}
# 146
# {'White Meat Chicken': 'MENU', 'Sauced Chicken Dish': 'MENU', 'Chicken': 'MENU', 'Onion Bhajis': 'MENU'}
# 174
# {'Tandoori Mixed Grill': 'MENU', 'Raita': 'MENU', 'Lamb Saag': 'MENU', 'Vegetable Soup': 'MENU', 'Dal': 'MENU', 'Lentils': 'MENU'}
# 112
# {'Vegetable Appetizer Platter': 'MENU'}
# 183
# {'Lamb Biryani': 'MENU', 'Chicken Tikka Masala': 'MENU'}
# 234
# {'Samosa': 'MENU', 'Lamb': 'MENU', 'Naan': 'MENU', 'Tandoori Chicken': 'MENU', 'Chicken Korma': 'MENU', 'Tandoori Mixed Grill': 'MENU', 'Fish': 'MENU'}
# 101
# {'Mango Ice Cream': 'MENU'}
# 65
# {'Chicken Tikka Masala': 'MENU', 'Naan': 'MENU', 'Samosas': 'MENU'}
# 144
# {'Plain Naan': 'MENU', 'Naan': 'MENU'}
# 93
# {'Vegetable Korma': 'MENU', 'Coconut Naan': 'MENU'}
# 222
# {}
# 102
# {'Tikka Masala': 'MENU', 'Saag Paneer': 'MENU', 'Garlic Naan': 'MENU'}
# 24
# {}
# 23
# {}
# 73
# {'Shrimp Tikka Masala': 'MENU'}
# 59
# {}
# 205
# {}
# 38
# {'Chicken Tikki Masala': 'MENU', 'Lamb Curry': 'MENU'}
# 222
# {'Palak Paneer': 'MENU', 'Paneer Cheese': 'MENU', 'Mango Lamb Curry': 'MENU', 'Garlic Naan': 'MENU', 'Naan': 'MENU', 'Basmati Rice': 'MENU', 'Bread': 'MENU'}
# 47
# {'Goat Curry': 'MENU', 'Lamb Saag': 'MENU', 'Butter Chicken': 'MENU'}
# 253
# {'Chutneys': 'MENU', 'Raitas': 'MENU', 'Chicken': 'MENU'}
# 70
# {'Butter Chicken': 'MENU', 'Naan': 'MENU'}
# 174
# {'Salad': 'MENU', 'Coconut Naan': 'MENU'}
# 348
# {'Lamb Masala': 'MENU', 'Tandoori Mixed Grill': 'MENU', 'Garlic Naan': 'MENU', 'Lamb Samosas': 'MENU', 'Naan': 'MENU', 'Samosas': 'MENU', 'Sauce': 'MENU'}
# 22
# {}
# 138
# {}
# 264
# {}
# 32
# {'Chicken Mango': 'MENU', 'Garlic Naan Bread': 'MENU'}
# 48
# {'Tikka': 'MENU', 'Kormas': 'MENU'}
# 1024
# {}
# 137
# {'Chicken': 'MENU', 'Beef': 'MENU', 'Lamb': 'MENU', 'Pork': 'MENU'}
# 70
# {'Butter Chicken': 'MENU', 'Naan': 'MENU'}
# 22
# {}
# 28
# {}
# 32
# {}
# 107
# {'Kebab Combo': 'MENU', 'Salad': 'MENU', 'Rice': 'MENU'}
# 46
# {}
# 455
# {'Chicken Wrap': 'MENU', 'Chicken': 'MENU', 'Beef': 'MENU'}
# 112
# {'Tandoori Chicken Leg Kabob': 'MENU', 'Kabob': 'MENU'}
# 141
# {'Salad': 'MENU', 'Rice': 'MENU'}
# 96
# {'Chicken Korma': 'MENU', 'Naan': 'MENU', 'Korma': 'MENU'}
# 196
# {'Chicken Kabob': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Hot Sauce': 'MENU'}
# 101
# {'Tandoori Kebob': 'MENU'}
# 98
# {'Kabab Karahi': 'MENU', 'Naan': 'MENU', 'Lamb Shank': 'MENU'}
# 23
# {}
# 26
# {}
# 93
# {'Rice': 'MENU', 'Salad': 'MENU'}
# 153
# {'Chicken Kebab Dinner': 'MENU', 'Chicken': 'MENU', 'Vegetable Stew': 'MENU', 'Bread': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Salads': 'MENU'}
# 219
# {'Tandoori Chicken': 'MENU', 'Chicken': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Tahini Sauces': 'MENU', 'Bread': 'MENU'}
# 171
# {'Lamb Shank': 'MENU', 'Beef Tikkas': 'MENU', 'Rice': 'MENU', 'Naans': 'MENU', 'Beef Karahi': 'MENU'}
# 45
# {'Bread': 'MENU'}
# 135
# {'Tandoori Chicken': 'MENU', 'Lamb Shank': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Hot Sauce': 'MENU'}
# 43
# {'Beef Tika': 'MENU', 'Kabob': 'MENU'}
# 46
# {'Chicken Kebab': 'MENU', 'Palak Sabzi': 'MENU', 'Tandoori': 'MENU'}
# 373
# {'Tandoori Chicken Dinner': 'MENU', 'Chicken': 'MENU', 'Chicken Tandoori': 'MENU', 'Chicken Breast': 'MENU', 'Chicken Pieces': 'MENU'}
# 232
# {'Beef Tikka Wrap': 'MENU', 'Rice': 'MENU', 'Beef': 'MENU', 'Vegetables': 'MENU', 'Yoghurt Sauce': 'MENU', 'Hot Sauce': 'MENU', 'Basmati Rice': 'MENU'}
# 32
# {'Sandwitch': 'MENU'}
# 70
# {'Salad': 'MENU'}
# 143
# {'Salad': 'MENU', 'Rice': 'MENU', 'Naan Bread': 'MENU', 'Tandoori Chicken': 'MENU', 'Green Chicken': 'MENU'}
# 212
# {'Sauce': 'MENU', 'Beef Seekh': 'MENU', 'Tikka Beef': 'MENU', 'Ground Chicken Seekh': 'MENU', 'Chicken Kabob': 'MENU', 'Veggie Wrap': 'MENU', 'Veggie Wraps': 'MENU'}
# 34
# {'Beef Tika': 'MENU', 'Kabob': 'MENU'}
# 38
# {}
# 60
# {'Chicken Seekh Wrap': 'MENU', 'Chicken Wrap': 'MENU'}
# 128
# {'Rice': 'MENU', 'Lamb Shank': 'MENU', 'Grilled Salmon': 'MENU', 'Naan': 'MENU', 'Crispy Fries': 'MENU', 'Kebabs': 'MENU'}
# 29
# {'Kabab': 'MENU', 'Rice': 'MENU'}
# 248
# {'Chicken': 'MENU', 'Chaplee Kebab': 'MENU', 'Kebab': 'MENU', 'Rice': 'MENU'}
# 220
# {'Meat Kebabs': 'MENU', 'Chicken': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Bread': 'MENU', 'Bulani': 'MENU', 'White Sauce': 'MENU'}
# 232
# {'Naan': 'MENU', 'Samosa': 'MENU', 'Lentil Soup': 'MENU', 'Salad': 'MENU', 'Papadums': 'MENU', 'Chutneys': 'MENU', 'Rice': 'MENU'}
# 73
# {'Soma': 'MENU'}
# 95
# {'Chicken Madras': 'MENU', 'Lamb Vindaloo': 'MENU', 'Salad': 'MENU', 'Lentil Soup': 'MENU', 'Naan': 'MENU'}
# 63
# {}
# 28
# {}
# 783
# {}
# 93
# {'Lentil Soup': 'MENU', 'Salad': 'MENU', 'Naan': 'MENU', 'Lamb': 'MENU', 'Saag Paneer': 'MENU'}
# 172
# {'Soma Grill': 'MENU', 'Soup': 'MENU'}
# 114
# {'Chicken Tikka': 'MENU', 'Goat Curry': 'MENU', 'Mataar Paneer': 'MENU', 'Fried Paneer': 'MENU', 'Naan': 'MENU'}
# 271
# {'Soma': 'MENU', 'Curry': 'MENU', 'Rice': 'MENU', 'Sauces': 'MENU', 'Fried Chicken': 'MENU', 'Pizza': 'MENU', 'Burgers': 'MENU'}
# 294
# {'Chicken Tikka Masala': 'MENU', 'Soup': 'MENU', 'Salad': 'MENU', 'Rice': 'MENU'}
# 226
# {'Ice Cream': 'MENU'}
# 222
# {'Tandoor': 'MENU', 'Chicken': 'MENU', 'Sauce': 'MENU', 'Naan Bred': 'MENU', 'Pita Bread': 'MENU'}
# 64
# {'Sauces': 'MENU', 'Soma Grill': 'MENU', 'Spicy Shrimp': 'MENU', 'Sauce': 'MENU'}
# 365
# {'Lentil Soup': 'MENU', 'Mixed Veggie': 'MENU', 'Curry': 'MENU', 'Soup': 'MENU', 'Shrimp Madras': 'MENU', 'Hot Sauce': 'MENU', 'Chana': 'MENU', 'Spinach Masala': 'MENU', 'Rice': 'MENU', 'Halwah': 'MENU'}
# 78
# {}
# 208
# {'Samosas': 'MENU', 'Green Sauce': 'MENU', 'Curry Chicken': 'MENU', 'Chickpeas': 'MENU', 'Naan': 'MENU', 'Rice': 'MENU'}
# 81
# {'Lentil Soup': 'MENU', 'Salad': 'MENU', 'Vegetable Samosa': 'MENU', 'Chicken Tikka Masala': 'MENU'}
# 100
# {'Dal': 'MENU', 'Lentil Soups': 'MENU'}
# 65
# {'Lentil Soup': 'MENU', 'Vegetables': 'MENU', 'Chicken Tikka': 'MENU', 'Marinated Goat': 'MENU'}
# 224
# {'Chicken Korma': 'MENU', 'Chicken Tikki Masala': 'MENU', 'Salad': 'MENU', 'Soup': 'MENU', 'Naan': 'MENU', 'Pita Bread': 'MENU'}
# 186
# {'Soma': 'MENU', 'Naan': 'MENU', 'Lentil Soup': 'MENU', 'Salad': 'MENU', 'Sauces': 'MENU', 'Lamb Vindaloo': 'MENU'}
# 56
# {'Massla Vada': 'MENU'}
# 136
# {'Veggie Samosas': 'MENU', 'Chicken Tikka Masala': 'MENU', 'Naan': 'MENU', 'Chicken Masala': 'MENU', 'Sauce': 'MENU', 'Lentil Soup': 'MENU', 'Salad': 'MENU'}
# 78
# {'Salad': 'MENU', 'Curried Goat': 'MENU'}
# 55
# {'Spicy Shrimp': 'MENU', 'Rice': 'MENU', 'Shrimp': 'MENU'}
# 108
# {'Beer': 'MENU', 'Paneer': 'MENU', 'Dosas': 'MENU', 'Rice': 'MENU', 'Spicy Shrimp': 'MENU', 'Lentil Soup': 'MENU', 'Hot Sauce': 'MENU'}
# 39
# {}
# 106
# {'Sultani Kebab Dinner': 'MENU', 'Kebabs': 'MENU', 'Rice': 'MENU', 'Naan': 'MENU', 'Tandoori Kebab': 'MENU', 'Chapli Kebab': 'MENU', 'Lamb Shank': 'MENU'}
# 81
# {'Fish': 'MENU', 'Salad': 'MENU', 'Naan Bread': 'MENU'}
# 156
# {'Veggie Wrap': 'MENU', 'Potato Bread': 'MENU', 'Bolani': 'MENU'}
# 103
# {'Tandoori Chicken': 'MENU', 'Vege Salad': 'MENU', 'Vegetables': 'MENU'}
# 101
# {'Tandoori Kabob Dinner': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Chicken': 'MENU', 'Naan Bread': 'MENU'}
# 258
# {'Tandoori Chicken Kabob Dinner': 'MENU', 'Rice': 'MENU', 'Chicken': 'MENU', 'Tandoori Chicken': 'MENU', 'Salad': 'MENU', 'Naan': 'MENU', 'Pamier Kabob': 'MENU', 'Tandoori Chicken Special': 'MENU', 'Beef Skewer': 'MENU', 'Pamier': 'MENU'}
# 101
# {'Sauce': 'MENU'}
# 33
# {}
# 153
# {'Kabob': 'MENU'}
# 401
# {'Kofta': 'MENU', 'Ground Beef Kabobs': 'MENU', 'Dinner': 'MENU', 'Chaplee Dinner': 'MENU', 'Sauce': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Naan': 'MENU', 'Qabulee Rice': 'MENU'}
# 67
# {'Tandoori Kabob': 'MENU', 'Rice': 'MENU', 'Naan': 'MENU', 'Vegetables': 'MENU'}
# 51
# {}
# 73
# {'Chaplee Kabob Dinner': 'MENU', 'Tandoori Wazeri Dinner': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Naan': 'MENU'}
# 50
# {'Kabobs': 'MENU'}
# 122
# {'Firni': 'MENU', 'Waziri Kabab': 'MENU', 'Choppan Kabab': 'MENU', 'Lamb Chops': 'MENU', 'Chicken Kabab': 'MENU'}
# 125
# {'Naan': 'MENU'}
# 264
# {'Chicken Breast Kabob': 'MENU', 'Tandoori Kabob': 'MENU', 'Chicken': 'MENU', 'Salad': 'MENU', 'Naan': 'MENU', 'Sauces': 'MENU', 'White Sauce': 'MENU'}
# 27
# {'Kaboli Rice': 'MENU'}
# 129
# {'Barg Kabob': 'MENU', 'Fish Tandoori': 'MENU'}
# 191
# {'Bbq': 'MENU', 'Tandoori Fish': 'MENU', 'Beef': 'MENU', 'Chicken': 'MENU', 'Wazeri Kabob Dinner': 'MENU', 'Chicken Breast Dinner': 'MENU', 'Doogh': 'MENU', 'Yoghurt Drink': 'MENU', 'Afghani Green Tea': 'MENU'}
# 114
# {'Naan': 'MENU', 'Bread': 'MENU'}
# 51
# {}
# 97
# {'Chicken': 'MENU'}
# 28
# {'Chicken': 'MENU'}
# 56
# {}
# 62
# {'Tandoori Chicken Breast': 'MENU'}
# 132
# {'Wazeri Kabob': 'MENU', 'Chicken Breast': 'MENU', 'Kofta Kabob Skewer': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Naan Bread': 'MENU'}
# 211
# {'Tandoori Wazeri Dinner': 'MENU', 'Lamb Shank': 'MENU', 'Naan': 'MENU', 'Doogh': 'MENU'}
# 256
# {'Kabob': 'MENU', 'Chaplee Kabob': 'MENU', 'Barg Kabob': 'MENU', 'Naan': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Barg': 'MENU', 'Chaplee': 'MENU', 'Afghan Kabob': 'MENU'}
# 391
# {'Tandoori Kabob': 'MENU', 'Chicken Breast Kabob': 'MENU', 'Chaplee Kabob': 'MENU', 'Chicken': 'MENU', 'Chicken Breast': 'MENU', 'Salad': 'MENU', 'Afghani Bread': 'MENU', 'Sauces': 'MENU', 'Dinner Platter': 'MENU', 'Basmati Rice': 'MENU', 'Garlic Sauce': 'MENU', 'Manakeesh': 'MENU', 'Baklawa': 'MENU'}
# 331
# {'Afghan Kabab': 'MENU'}
# 53
# {}
# 33
# {}
# 100
# {'Naan': 'MENU', 'Kabob': 'MENU', 'Tandoori Chicken': 'MENU', 'Rice': 'MENU'}
# 137
# {'Tandoori Wazeri Dinner': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Naan': 'MENU', 'Barg Kabab': 'MENU', 'Bread': 'MENU'}
# 273
# {'Salad': 'MENU', 'Salads': 'MENU', 'Salad Dinners': 'MENU', 'Rice': 'MENU', 'Naans': 'MENU'}
# 100
# {'Bolani': 'MENU', 'Ferni': 'MENU', 'Fish Tandoori': 'MENU', 'Fish': 'MENU', 'Paneer Kaboobs': 'MENU'}
# 100
# {'Wazieri Kebab': 'MENU', 'Chicken': 'MENU', 'Kofta': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Afghan Bread': 'MENU'}
# 62
# {'Kabob': 'MENU', 'Tandoori Kabob': 'MENU', 'Salad': 'MENU', 'Naan': 'MENU'}
# 156
# {'Kebobs': 'MENU', 'Kebabs': 'MENU', 'Chaplin Kebabs': 'MENU', 'Kebab': 'MENU'}
# 28
# {}
# 101
# {'Chicken': 'MENU', 'Beef': 'MENU', 'Fish': 'MENU', 'Salads': 'MENU'}
# 91
# {'Chicken Kebab': 'MENU', 'Naan': 'MENU'}
# 45
# {'Naans': 'MENU', 'Fries': 'MENU'}
# 86
# {'Chapli Kabobs': 'MENU', 'Chicken Tikka': 'MENU'}
# 83
# {'Hot Sauce': 'MENU', 'Naan Bread': 'MENU'}
# 58
# {'Chicken Beast Kabob': 'MENU', 'Salad': 'MENU', 'Naan': 'MENU'}
# 43
# {'Kobobs': 'MENU'}
# 31
# {'Chicken Skewers': 'MENU'}
# 124
# {'Kebabs': 'MENU', 'Barg Kebab': 'MENU', 'Rice': 'MENU', 'Naan Bread': 'MENU'}
# 30
# {'Kofta Kabob': 'MENU', 'Fries': 'MENU'}
# 117
# {'Chapli Kebab Diner Platter': 'MENU', 'Beef Kebabs': 'MENU', 'Salad': 'MENU', 'Basmati Rice': 'MENU', 'Afghani Naan': 'MENU', 'Chicken Breast Stew': 'MENU', 'Korma': 'MENU', 'Tandoori Naan': 'MENU'}
# 296
# {'Wazeri Kabab Dinner': 'MENU', 'Chicken': 'MENU', 'Kofta Kabab Sultani Kabab Dinner': 'MENU', 'Kofta Kabab Chaplee Kabab Dinner': 'MENU', 'Spicy Minced Meat Patties': 'MENU', 'Rice': 'MENU', 'Chaplee': 'MENU', 'Sauces': 'MENU', 'Red Sauce': 'MENU', 'Tomato Sauce': 'MENU', 'White': 'MENU'}
# 214
# {'Afghani Rice': 'MENU', 'Chicken Pieces': 'MENU', 'Barg Kabab': 'MENU', 'Bread': 'MENU', 'Chilli Sauce': 'MENU', 'Yogurt Sauce': 'MENU', 'Bolanee': 'MENU', 'Lamb Shank': 'MENU', 'Rice': 'MENU'}
# 151
# {'Afghani Grills': 'MENU', 'Rice': 'MENU'}
# 45
# {}
# 99
# {'Chicken Dinner': 'MENU', 'Chicken': 'MENU', 'Rice': 'MENU', 'Naan Bread': 'MENU', 'Salad': 'MENU'}
# 25
# {'Kabobs': 'MENU', 'Bread': 'MENU'}
# 38
# {}
# 240
# {'Chicken': 'MENU', 'Half Chicken Dinner': 'MENU', 'Beef': 'MENU', 'Sultani Dinner': 'MENU', 'Burg': 'MENU', 'Filet': 'MENU', 'White Sauce': 'MENU', 'Boulani': 'MENU', 'Kheer': 'MENU'}
# 249
# {'Chaplee Kebabs': 'MENU', 'Beef Tikka': 'MENU', 'Rice': 'MENU', 'Bread': 'MENU', 'Salad': 'MENU', 'Nan Combo': 'MENU'}
# 80
# {'Sauce': 'MENU'}
# 55
# {'Meat Kabob': 'MENU', 'Hot Sauce': 'MENU'}
# 128
# {'Chapli Kebabs': 'MENU', 'Rice': 'MENU', 'Naan': 'MENU', 'Salad': 'MENU', 'Sauces': 'MENU'}
# 97
# {'Kabobs': 'MENU', 'Chapli Kababs': 'MENU', 'Tandoori Chicken Boneless': 'MENU'}
# 193
# {}
# 114
# {'Afghan Kabob': 'MENU', 'Chicken': 'MENU', 'Kabob': 'MENU', 'Fish': 'MENU', 'Spicy Fish': 'MENU'}
# 114
# {'Bread': 'MENU', 'Salad': 'MENU', 'White And Red Sauce': 'MENU', 'Sultani Dinner': 'MENU', 'Chicken Dinner': 'MENU'}
# 30
# {'Salads': 'MENU', 'Bread': 'MENU'}
# 113
# {'Tandoori Chicken Kabob Dinner': 'MENU', 'Rice': 'MENU', 'Chicken': 'MENU', 'Naan': 'MENU', 'Boulagnee': 'MENU'}
# 52
# {}
# 102
# {'Chicken': 'MENU', 'Lamb': 'MENU', 'Beef': 'MENU', 'Fish': 'MENU', 'Mantoo': 'MENU'}
# 172
# {'Lamb': 'MENU', 'Chicken': 'MENU', 'Beef': 'MENU', 'Chicken Biryani': 'MENU', 'Biryani': 'MENU'}
# 103
# {'Bread': 'MENU', 'Chaplee Kebob': 'MENU', 'Tandoori Fish': 'MENU'}
# 55
# {'Chicken Kofta Wrap': 'MENU', 'Chicken': 'MENU'}
# 31
# {'Sultani Dinner': 'MENU', 'Naans': 'MENU', 'Red Sauce': 'MENU'}
# 136
# {'Bolani': 'MENU', 'Tandoori Chicken': 'MENU', 'Chaplee Kabab': 'MENU', 'Fish': 'MENU'}
# 74
# {'Tandoori Platter': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Naan Bread': 'MENU'}
# 60
# {'Chicken': 'MENU', 'Kebab': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU'}
# 124
# {}
# 101
# {'Waziri': 'MENU', 'Chapli': 'MENU'}
# 20
# {'Lamb Shank': 'MENU', 'Fish': 'MENU', 'Chaplee Kabob': 'MENU'}
# 116
# {'Wazeri Platter': 'MENU', 'Grilled Chicken': 'MENU', 'Beef Kafta Kabab': 'MENU', 'Rice': 'MENU', 'Qabuli Pulao': 'MENU'}
# 109
# {'Tandoori': 'MENU', 'Bbq Chicken Breast': 'MENU', 'Lamb Shank': 'MENU', 'Kofta Kabobs': 'MENU', 'Bread': 'MENU'}
# 182
# {'Chicken Breast Kabob': 'MENU', 'Tandoori Kabob': 'MENU', 'Fish': 'MENU', 'Salad': 'MENU', 'Naan': 'MENU', 'Rice': 'MENU'}
# 389
# {'Chaplee Kabob Dinner': 'MENU', 'Spicy Ground Beef': 'MENU', 'Rice': 'MENU', 'Wazeri Kabob': 'MENU', 'Chicken': 'MENU', 'Kofta': 'MENU', 'Salad': 'MENU', 'Naan': 'MENU', 'Chaplee': 'MENU', 'Squashed Burger Patty': 'MENU', 'Kabob': 'MENU', 'Tomato': 'MENU', 'Sauce': 'MENU', 'Dough': 'MENU', 'Lassi': 'MENU', 'Chaplee Dinner': 'MENU'}
# 147
# {'Kabobs': 'MENU'}
# 381
# {'Kabobs': 'MENU', 'Tandoori Chicken': 'MENU', 'Beef Tikka': 'MENU', 'Wazeri': 'MENU', 'Naan': 'MENU', 'Tzatzaki Sauce': 'MENU'}
# 56
# {'Chicken Tandoori': 'MENU', 'Chicken': 'MENU'}
# 24
# {'Ground Beef Kabobs': 'MENU'}
# 86
# {'Chicken': 'MENU', 'Lamb': 'MENU', 'Beef': 'MENU', 'Dipping Sauces': 'MENU', 'Bread': 'MENU'}
# 109
# {}
# 121
# {'Chaplee Kebab': 'MENU'}
# 58
# {}
# 165
# {'Tandoori Fish': 'MENU', 'Chicken': 'MENU'}
# 186
# {'Kabob': 'MENU', 'Fish': 'MENU', 'Chicken': 'MENU', 'Naan': 'MENU'}
# 251
# {'Tandoori Chicken Wrap': 'MENU', 'Afghan Salad': 'MENU', 'Salad': 'MENU'}
# 45
# {}
# 52
# {}
# 93
# {'Kabobs': 'MENU', 'Chicken Tikka Kabobs': 'MENU', 'Rice': 'MENU'}
# 31
# {'Kabob': 'MENU'}
# 345
# {'Chicken Kofta Salad': 'MENU', 'Bread': 'MENU', 'Sea Bass Dinner': 'MENU', 'Chicken Kofta': 'MENU', 'Chapli Kebab': 'MENU', 'Chicken Koftas': 'MENU', 'Salad': 'MENU', 'Bass': 'MENU', 'Chapli': 'MENU', 'Rice': 'MENU', 'Chicken': 'MENU', 'Sea Bass': 'MENU', 'Fish': 'MENU'}
# 101
# {'Tandoori Wrap': 'MENU'}
# 112
# {'Beef': 'MENU', 'Chicken Kebab': 'MENU', 'Rice': 'MENU', 'Naan': 'MENU', 'Salad': 'MENU', 'Hamburger': 'MENU', 'Kebab': 'MENU'}
# 410
# {'Red Sauce': 'MENU', 'Kabob': 'MENU', 'Sauce': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Naan': 'MENU', 'Sea Bass': 'MENU', 'Fish': 'MENU', 'Tandoori': 'MENU', 'Basmati Rice': 'MENU', 'Salads': 'MENU', 'Rilled': 'MENU'}
# 96
# {}
# 23
# {'Tandoori Plate': 'MENU'}
# 102
# {'Chaplee Kabob Dinner': 'MENU', 'Kabobs': 'MENU', 'Chaplee': 'MENU', 'Chicken Skrewers': 'MENU'}
# 62
# {}
# 27
# {}
# 708
# {}
# 77
# {'Bread': 'MENU'}
# 37
# {}
# 70
# {'Fish Dinner': 'MENU', 'Chicken Breast Kabob': 'MENU', 'Kofta Kabob': 'MENU', 'Fish': 'MENU'}
# 106
# {'Rice': 'MENU'}
# 22
# {}
# 107
# {'Rice': 'MENU', 'Chicken': 'MENU'}
# 281
# {'Chicken Kabob Salad': 'MENU', 'Chicken': 'MENU', 'Salad': 'MENU', 'Pico': 'MENU', 'Sauce': 'MENU', 'Rice': 'MENU', 'Chicken Meal': 'MENU', 'Green Tea': 'MENU'}
# 32
# {'Kabob': 'MENU'}
# 53
# {'Afghani Cuisine': 'MENU', 'Chapli Kabob': 'MENU', 'Tikkah': 'MENU', 'Qorma': 'MENU'}
# 235
# {'Kabuli Palau': 'MENU', 'Rice': 'MENU', 'Lamb Stew': 'MENU', 'Yakhnee': 'MENU', 'White Rice': 'MENU', 'Kabobs': 'MENU', 'Naan': 'MENU', 'Afghan Bread': 'MENU', 'Bread': 'MENU', 'Bolani': 'MENU'}
# 138
# {'Lamb Shank Dinner': 'MENU', 'Chicken Qorma': 'MENU', 'Shank': 'MENU', 'Salad': 'MENU', 'Chopan Grill': 'MENU', 'Watan Kabob': 'MENU'}
# 64
# {'Chicken': 'MENU', 'Beef': 'MENU', 'Rice': 'MENU', 'Naan': 'MENU', 'Chicken Tikka': 'MENU'}
# 308
# {'Beef Kofta': 'MENU', 'Salad': 'MENU', 'Naan': 'MENU', 'Rice': 'MENU', 'Spicy': 'MENU', 'Sauce': 'MENU'}
# 47
# {}
# 133
# {'Lamp Kabob Dinner': 'MENU', 'Beef Kabob': 'MENU', 'Bread': 'MENU', 'Spicy Tomato Sauce': 'MENU'}
# 260
# {'Beef Tikka Kabob Dinner': 'MENU', 'Beef': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Afghan Bread': 'MENU', 'Basmati Rice': 'MENU', 'Diced Tomato Salad': 'MENU', 'Iceberg Lettuce Salad': 'MENU', 'Naan': 'MENU', 'Bread': 'MENU'}
# 41
# {'Tandoori Chicken Dinner': 'MENU'}
# 26
# {'Tandori Chicken': 'MENU', 'Naan': 'MENU'}
# 48
# {'Tandoori Chicken': 'MENU', 'Fish Tandoori': 'MENU', 'Beef': 'MENU'}
# 94
# {}
# 205
# {'Lamb': 'MENU', 'Tandoori Chicken': 'MENU', 'Beef Kabob': 'MENU', 'Tandoori': 'MENU', 'Chicken': 'MENU', 'Kabob': 'MENU'}
# 33
# {}
# 226
# {'Kofta': 'MENU', 'Tandoori Chicken': 'MENU', 'Bread': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU'}
# 64
# {}
# 61
# {}
# 86
# {'Tandoori Chicken Dinner': 'MENU', 'Rice': 'MENU', 'Bread': 'MENU'}
# 46
# {}
# 91
# {}
# 77
# {'Tandoori Wazeri Platter': 'MENU', 'Afghani Bbq': 'MENU', 'Chicken Kabab': 'MENU', 'Beef': 'MENU', 'Crisp Salad': 'MENU', 'Creamy Sauce': 'MENU', 'Savoury Rice': 'MENU', 'Naan': 'MENU'}
# 172
# {'Kebobs': 'MENU', 'Kebob': 'MENU', 'Waziri Dinner': 'MENU', 'Ground Beef': 'MENU', 'Chicken Breast Skewers': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Afghan Bread': 'MENU', 'Bread': 'MENU'}
# 32
# {'Rice': 'MENU'}
# 98
# {'Bolani': 'MENU', 'Chicken Breast Kabab Dinner': 'MENU', 'Dinner Rice': 'MENU', 'Kabuli Rice': 'MENU', 'Kababs': 'MENU'}
# 67
# {}
# 196
# {'Chapli Kabab Dinner': 'MENU', 'Rice': 'MENU', 'Naan': 'MENU', 'Salad': 'MENU', 'Salads': 'MENU', 'Red Sauce': 'MENU', 'Ranch Sauce': 'MENU', 'Chapli Kabab': 'MENU'}
# 119
# {}
# 35
# {}
# 83
# {'Wazeri Kabob Dinner': 'MENU', 'Chicken': 'MENU', 'Beef': 'MENU', 'Rice': 'MENU'}
# 347
# {'Chicken Breast Kabob': 'MENU', 'Platter': 'MENU', 'Salad': 'MENU', 'Rice': 'MENU', 'Afghan Bread': 'MENU', 'Chicken': 'MENU', 'Chicken Breasts': 'MENU', 'Grill': 'MENU', 'Tandoori': 'MENU', 'Fish Dinner': 'MENU'}
# 180
# {'Kabob': 'MENU', 'Wazeri Kabob': 'MENU', 'Chicken': 'MENU', 'Beef': 'MENU', 'Salad': 'MENU', 'Naan': 'MENU', 'Firni': 'MENU', 'Sweet Custard': 'MENU'}
# 124
# {'Chicken Wrap': 'MENU', 'Chicken': 'MENU', 'Salad': 'MENU', 'Naan Bread': 'MENU', 'Kebabs': 'MENU'}
# 24
# {'Naan': 'MENU', 'Chicken': 'MENU'}
# 80
# {'Kebabs': 'MENU'}
# 172
# {}
# 112
# {'Tandoori Chicken': 'MENU', 'Afghani Naan': 'MENU'}
# 59
# {'Sauces': 'MENU', 'Chicken': 'MENU'}
# 31
# {}
# 88
# {'Chaplee Kabobs': 'MENU', 'Chicken Skrewer': 'MENU', 'Kabobs': 'MENU'}
# 135
# {'Kabob': 'MENU', 'Bread': 'MENU', 'Kabobs': 'MENU'}
# 305
# {}
# 102
# {'Rice': 'MENU', 'Kabobs': 'MENU', 'Chicken': 'MENU'}
# 237
# {'Tandoori Chicken': 'MENU', 'Chickens': 'MENU', 'Lamb': 'MENU', 'Beef Kabob': 'MENU', 'Tandoori': 'MENU', 'Chicken': 'MENU', 'Kabob': 'MENU'}
# 99
# {}
# 197
# {'Ceaser Salad': 'MENU', 'Chicken': 'MENU', 'Salads': 'MENU', 'Salad': 'MENU', 'Fries': 'MENU'}
# 94
# {'Tandoori Fish': 'MENU', 'Chicken': 'MENU'}
# 120
# {'Grilled Fish': 'MENU', 'Chicken Skewer': 'MENU'}
# 454
# {'Waziri Chicken Tandoori Kabob Dinner': 'MENU', 'Platter': 'MENU', 'Tandoori Chicken': 'MENU', 'Kofta Kabab': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Sauces': 'MENU', 'Afghani Bread': 'MENU', 'Bbq': 'MENU', 'Kabob': 'MENU', 'Naan': 'MENU'}
# 150
# {'Naan Bread': 'MENU', 'Salad': 'MENU', 'Grilled Kabob': 'MENU', 'Tenderloin': 'MENU', 'Tandoori Chicken': 'MENU'}
# 42
# {'Lamb Shank': 'MENU'}
# 41
# {'Nan Bread': 'MENU'}
# 85
# {'Tandoori Fish': 'MENU', 'Lamb Shank': 'MENU', 'Rice': 'MENU', 'Lamb': 'MENU'}
# 92
# {'Kabob': 'MENU', 'Rice': 'MENU', 'Bread': 'MENU', 'Salad': 'MENU'}
# 23
# {'Chaplis': 'MENU'}
# 60
# {}
# 38
# {}
# 33
# {}
# 86
# {}
# 58
# {}
# 35
# {'Red Sauce': 'MENU'}
# 68
# {'Garlic Sauce': 'MENU', 'Chaplee Kabob': 'MENU', 'Basmati': 'MENU', 'Salad': 'MENU', 'Naan': 'MENU'}
# 171
# {'Cubed Chicken': 'MENU', 'Kafta': 'MENU', 'Salad': 'MENU', 'Naan': 'MENU'}
# 138
# {'Chapli Kabob': 'MENU', 'Bread': 'MENU', 'Naan': 'MENU', 'Rice': 'MENU', 'Lamb Shank': 'MENU', 'Kofta': 'MENU'}
# 90
# {'Tandoori Wazeri': 'MENU', 'Tandoori Chicken Breasts': 'MENU', 'Kofta Kabob': 'MENU', 'Sauce': 'MENU'}
# 152
# {'Naan': 'MENU', 'Kebob Skewers': 'MENU', 'Ground Beef Kebob Skewers': 'MENU', 'Chapli Kabab': 'MENU', 'Chutney': 'MENU'}
# 49
# {}
# 44
# {'Naan': 'MENU', 'Steak': 'MENU', 'Kofta Combo': 'MENU'}
# 77
# {}
# 109
# {'Bread': 'MENU', 'White Sauce': 'MENU', 'Salad': 'MENU', 'Tandoori Chicken': 'MENU'}
# 14
# {}
# 137
# {'Platter': 'MENU', 'Chicken': 'MENU', 'Lamb': 'MENU', 'Beef': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Pita': 'MENU', 'Spicy Tomato Chutney': 'MENU', 'Sauce': 'MENU'}
# 106
# {'Kebab Dishes': 'MENU', 'Tandoori Chicken Dinner': 'MENU', 'Naans': 'MENU', 'Chicken': 'MENU', 'Kabobs': 'MENU', 'Salad': 'MENU'}
# 58
# {'Chicken': 'MENU', 'Beef': 'MENU', 'Rice': 'MENU', 'Naans': 'MENU'}
# 293
# {'Bass Fish': 'MENU', 'Rice': 'MENU', 'Fish': 'MENU', 'Bread': 'MENU', 'Salad': 'MENU', 'Sauce': 'MENU', 'Burger': 'MENU'}
# 122
# {}
# 124
# {'Chapli Kebab': 'MENU', 'Kofta Kebab': 'MENU', 'Salad': 'MENU', 'Beet Kebab': 'MENU', 'Naan': 'MENU'}
# 234
# {'Kofta Kabob': 'MENU', 'Naan': 'MENU', 'Kofta': 'MENU', 'Kabob': 'MENU', 'Bread': 'MENU'}
# 219
# {'Tandoori Fish Dinner': 'MENU', 'Kofta Kabob Dinner': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Naan': 'MENU'}
# 220
# {'Beef Tikka Kabob': 'MENU', 'Beef': 'MENU', 'Salad': 'MENU', 'Bread': 'MENU', 'Rice': 'MENU', 'Lamb Shank Dinner': 'MENU', 'Shank': 'MENU', 'Lamb': 'MENU', 'Lamb Shank': 'MENU', 'Vegetables': 'MENU', 'Chopan Lamb': 'MENU', 'Kofta Beef': 'MENU', 'Watan Mantoo': 'MENU', 'Dumpling': 'MENU'}
# 22
# {'Chapli Kabob': 'MENU', 'Half Chicken': 'MENU'}
# 119
# {'Bolani': 'MENU', 'Grilled Chicken Dinner': 'MENU', 'Dinner Rice': 'MENU', 'Kabuli Rice': 'MENU', 'Kababs': 'MENU', 'Chapli': 'MENU', 'Chicken Tikka Kabab': 'MENU'}
# 331
# {'Naan': 'MENU', 'Bread': 'MENU', 'Rice': 'MENU', 'Salad': 'MENU', 'Barg Kabob': 'MENU', 'Kofta Kabob': 'MENU'}
# 45
# {}
# 48
# {'Scheshwan Chicken': 'MENU', 'Chilli Chicken': 'MENU'}
# 75
# {'Chicken': 'MENU', 'Fried Rice': 'MENU'}
# 25
# {}
# 82
# {'Spring Rolls': 'MENU', 'Hakka Fried Rice': 'MENU', 'Hakka Fried Noodles': 'MENU', 'Chilli Chicken': 'MENU'}
# 23
# {}
# 37
# {}
# 22
# {'Honey Garlic Chicken': 'MENU'}
# 142
# {'Tiger Prawns': 'MENU', 'Tso Sauce': 'MENU'}
# 154
# {'Dinner': 'MENU', 'Noodles': 'MENU'}
# 52
# {}
# 49
# {'Chicken': 'MENU', 'Noodles': 'MENU', 'Garlic Chicken': 'MENU'}
# 155
# {'Fried Rice': 'MENU', 'Noodles': 'MENU', 'Chicken': 'MENU', 'Hot And Sour Soup': 'MENU', 'Chicken Corn Soup': 'MENU', 'Soups': 'MENU'}
# 78
# {'Shrimp': 'MENU', 'Brown Sauce': 'MENU', 'Chili Chicken': 'MENU'}
# 29
# {'Chicken Pakora': 'MENU'}
# 26
# {}
# 82
# {}
# 148
# {'Fish': 'MENU', 'Chicken': 'MENU', 'Goat': 'MENU'}
# 107
# {'Chicken': 'MENU', 'Chicken Piece': 'MENU'}
# 36
# {'Monagadi Kodi Vepudu': 'MENU', 'Mutton Dum Biriyani': 'MENU'}
# 38
# {'Briyani': 'MENU'}
# 135
# {}
# 69
# {}
# 31
# {'Biryani': 'MENU', 'Cashew Chicken': 'MENU'}
# 32
# {}
# 35
# {'Biryani': 'MENU'}
# 40
# {'Butter Chicken': 'MENU'}
# 231
# {'Onion Pokuras': 'MENU', 'Naan': 'MENU', 'Palak Paneer': 'MENU'}
# 38
# {'Chicken Tika Masala': 'MENU'}
# 25
# {}
# 28
# {}
# 32
# {}
# 37
# {}
# 129
# {'Biriyani': 'MENU'}
# 109
# {'Sauces': 'MENU'}
# 47
# {'Biryani': 'MENU'}
# 38
# {}
# 52
# {}
# 85
# {}
# 108
# {}
# 43
# {}
# 122
# {}
# 142
# {'Sweet Corn Soup': 'MENU', 'Curry Leaf Chicken Fry': 'MENU', 'Panner Butter Masala': 'MENU', 'Karaikudi Chicken Curry': 'MENU', 'Chicken Dum Biryani': 'MENU', 'Veg Fried Rice': 'MENU', 'Naan': 'MENU', 'Mango Kulfi': 'MENU'}
# 25
# {}
# 160
# {}
# 62
# {}
# 50
# {'Mutton Dum Briyani': 'MENU', 'Palak Paneer': 'MENU', 'Butter Naan': 'MENU'}
# 40
# {'Goat Dum Biryani': 'MENU', 'Keema Biryani': 'MENU', 'Monagadi Kodi Vepudu': 'MENU'}
# 200
# {'Naan': 'MENU', 'Chestnut Manchurian': 'MENU', 'Schezwan Fried Rice': 'MENU'}
# 173
# {'Paneer Chettinad Gravy': 'MENU', 'Naan': 'MENU', 'Chicken Lollipops': 'MENU'}
# 156
# {'Chicken Tikka Masala': 'MENU', 'Garlic Naan': 'MENU', 'Stuffed Eggplant': 'MENU', 'Eggplant': 'MENU', 'Nutella Dosa': 'MENU'}
# 122
# {'Upma': 'MENU', 'Cabbage Curry': 'MENU', 'Briyani': 'MENU'}
# 62
# {}
# 292
# {'Manchurian Gobi': 'MENU', 'Malai Kofta': 'MENU', 'Butter Paneer': 'MENU', 'Garlic Naan': 'MENU'}
# 315
# {'Gobi': 'MENU', 'Veg Dum Biriyani': 'MENU', 'Veg Biriyani': 'MENU', 'Chicken Biriyani': 'MENU', 'Paneer Pulao': 'MENU', 'Rice': 'MENU', 'Aloo Bonda': 'MENU', 'Fried Baby Corn': 'MENU', 'Sambar': 'MENU', 'Uttapam': 'MENU'}
# 45
# {}
# 34
# {'Dosa': 'MENU', 'Masala Dosa': 'MENU', 'Paneer Dosa': 'MENU'}
# 38
# {'Curry Leaf Paneer': 'MENU', 'Paneer Karaikudi': 'MENU'}
# 39
# {'Chicken Biryani': 'MENU', 'Ulvacharu Biryani': 'MENU'}
# 352
# {'Corn Vepudu': 'MENU', 'Kadai Chicken': 'MENU', 'Tomato': 'MENU', 'Sauce': 'MENU', 'Saag Paneer': 'MENU', 'Garlic Naan': 'MENU'}
# 138
# {'Naan': 'MENU', 'Parka': 'MENU', 'Samosas': 'MENU', 'Veggie Spring Rolls': 'MENU'}
# 77
# {}
# 134
# {}
# 373
# {'Tandoori Chicken': 'MENU', 'Chicken Korma': 'MENU', 'Dosa': 'MENU', 'Chutneys': 'MENU', 'Goat': 'MENU', 'Sauces': 'MENU', 'Mango Lassi': 'MENU', 'Double Ka Meeta': 'MENU', 'Apple Pie': 'MENU', 'Bread Pudding': 'MENU'}
# 58
# {}
# 33
# {}
# 145
# {'Chicken': 'MENU', 'Goat': 'MENU', 'Fish': 'MENU', 'Vermicelli Kheer': 'MENU'}
# 124
# {'Pakora': 'MENU', 'Idly': 'MENU', 'Sambar': 'MENU', 'Fried Rice': 'MENU', 'Pulao': 'MENU', 'Biriyani': 'MENU', 'Chicken Curries': 'MENU', 'Chicken Roast': 'MENU', 'Tandoor Chicken': 'MENU', 'Kesari': 'MENU', 'Gajar Halwa': 'MENU', 'Strawberry Shortcake': 'MENU', 'Chocolate Mousse': 'MENU'}
# 269
# {'Ghee Roast': 'MENU', 'Madras Goat Curry': 'MENU', 'Goat': 'MENU', 'Chicken Curry': 'MENU', 'Madras Chicken Curry': 'MENU', 'Goat Curry': 'MENU', 'Chicken': 'MENU', 'Naan': 'MENU', 'Bread': 'MENU', 'Veg Curry': 'MENU'}
# 251
# {'Vegetable': 'MENU', 'Chicken': 'MENU'}
# 40
# {'Paneer': 'MENU', 'Chicken Fry Biryani': 'MENU'}
# 118
# {}
# 113
# {'Pongal': 'MENU', 'Samosa': 'MENU', 'Tamarind Chutney': 'MENU', 'Tindora Fry': 'MENU', 'Okra Fry': 'MENU', 'Medhu Vada': 'MENU', 'Curd Rice': 'MENU', 'Basundi': 'MENU', 'Fruit Custard': 'MENU', 'Dosa': 'MENU'}
# 121
# {'Naan': 'MENU', 'Sambhar': 'MENU'}
# 845
# {}
# 135
# {'Ulavacharu Panner Biryani': 'MENU', 'Biryani': 'MENU'}
# 91
# {'Veg': 'MENU', 'Mutton Biryani': 'MENU'}
# 56
# {}
# 508
# {'Monagadi Gobi': 'MENU', 'Veg Samosas': 'MENU', 'Vindaloo Chicken': 'MENU', 'Masala Shrimp': 'MENU', 'Cngura': 'MENU', 'Shrimp': 'MENU', 'Garlic & Butter Naan': 'MENU', 'Chicken Biryani': 'MENU', 'Naan': 'MENU', 'Beer': 'MENU'}
# 86
# {}
# 34
# {}
# 171
# {'Paneer Biryani': 'MENU', 'Chilli Gobi': 'MENU', 'Chicken Biryani': 'MENU', 'Biryani': 'MENU'}
# 136
# {'Lamb Khorma': 'MENU'}
# 71
# {'Chicken': 'MENU', 'Medu Wada': 'MENU', 'Daal': 'MENU', 'Paneer Tikka Masala': 'MENU'}
# 81
# {}
# 89
# {'Tikka Masala': 'MENU', 'Garlic Naan': 'MENU'}
# 56
# {}
# 42
# {'Biryani': 'MENU', 'Rajugari Kodi Pulao': 'MENU'}
# 28
# {}
# 73
# {}
# 107
# {'Dosa': 'MENU', 'Mango Lassie': 'MENU', 'Chicken': 'MENU', 'Mutton Koththu': 'MENU'}
# 49
# {'Dosas': 'MENU', 'Madras': 'MENU', 'Paneer': 'MENU', 'Butter Chicken': 'MENU', 'Coconut Rice': 'MENU', 'Chili Chicken': 'MENU'}
# 83
# {'Dosa': 'MENU', 'Chicken Tikka Masala': 'MENU'}
# 223
# {'Lentil Vadai': 'MENU', 'Sambar': 'MENU', 'Dosas': 'MENU', 'Potato Marsala': 'MENU', 'Cheese Dosa': 'MENU', 'Butter Chicken': 'MENU', 'Dosa': 'MENU'}
# 34
# {'Supreme Dosa': 'MENU'}
# 65
# {'Chilli Dosa': 'MENU', 'Ginger Tea': 'MENU'}
# 36
# {'Samosa': 'MENU', 'Hot Sauce': 'MENU', 'Kerala Chicken': 'MENU', 'Chilli Chicken Dosa': 'MENU'}
# 81
# {}
# 368
# {'Dosas': 'MENU', 'Chicken Chettinad Kurma': 'MENU', 'Curry': 'MENU', 'Malabar Paratha': 'MENU', 'Basmati': 'MENU', 'Pondicherry Meen Fried Fish': 'MENU', 'Dipping Sauce': 'MENU', 'Lamb Chettinad Kurma': 'MENU', 'Sauce': 'MENU', 'Mutton': 'MENU', 'Boneless Chicken': 'MENU', 'Paratha': 'MENU'}
# 145
# {'Butter Chicken Dosa': 'MENU', 'Coconut Rice': 'MENU'}
# 104
# {'Masala Dosa': 'MENU', 'Hosur 65': 'MENU', 'Fried Boneless Fish': 'MENU', 'Supreme Ambur Chicken Biryani': 'MENU', 'Kothu Mutton': 'MENU'}
# 213
# {'Dosas': 'MENU', 'Butter Chicken Dosa': 'MENU', 'Coconut Rice': 'MENU'}
# 62
# {'Mutton Dosa': 'MENU'}
# 44
# {'Dhaal': 'MENU'}
# 218
# {'Chickpea': 'MENU', 'Chicken Curries': 'MENU', 'Chicken': 'MENU', 'Naan': 'MENU', 'Dhabha': 'MENU'}
# 72
# {'Butter Chicken': 'MENU', 'Paneer Special': 'MENU', 'Chickpeas': 'MENU', 'Kidney Beans': 'MENU', 'Nan': 'MENU', 'Curry': 'MENU'}
# 75
# {'Paneer': 'MENU', 'Naan': 'MENU', 'Butter Chicken': 'MENU'}
# 143
# {'Vegetarian Biryani': 'MENU', 'Aloo Jalfrezi': 'MENU', 'Samosa': 'MENU'}
# 93
# {'Iceberg Lettuce Salad': 'MENU'}
# 61
# {'Rice': 'MENU', 'Coconut Fish': 'MENU', 'Salmon': 'MENU', 'Paneer': 'MENU'}
# 70
# {'Naan Bread': 'MENU', 'Chicken Tikka': 'MENU', 'Naan': 'MENU', 'Lassi': 'MENU', 'Vegetables': 'MENU'}
# 76
# {'Snacks': 'MENU', 'Wada Pao': 'MENU', 'Samosas': 'MENU'}
# 55
# {'Butter Chicken': 'MENU', 'Salad': 'MENU'}
# 74
# {'Butter Chicken': 'MENU', 'Chicken': 'MENU', 'Chickpeas': 'MENU', 'Rice': 'MENU'}
# 161
# {}
# 110
# {'Rice': 'MENU', 'Salad': 'MENU'}
# 190
# {'Lentil Curry': 'MENU', 'Naan': 'MENU'}
# 195
# {'Butter Chicken': 'MENU', 'Naan': 'MENU', 'Rice': 'MENU', 'Curry': 'MENU', 'Vegetables': 'MENU', 'Naan Bread': 'MENU'}
# 262
# {'Biryani': 'MENU'}
# 30
# {}
# 58
# {'Eggplant': 'MENU', 'Lentil Dishes': 'MENU'}
# 169
# {'Chicken Masala': 'MENU', 'Chicken': 'MENU', 'Lamb': 'MENU', 'Shirmp Curry': 'MENU'}
# 65
# {}
# 52
# {'Sauces': 'MENU', 'Paneer Tika Masala': 'MENU', 'Zafrani Rice': 'MENU', 'Garlic Naan': 'MENU'}
# 265
# {}
# 156
# {}
# 34
# {}
# 53
# {}
# 91
# {'Chana Masala': 'MENU', 'Chili Chicken': 'MENU', 'Naan': 'MENU', 'Whole Wheat Puri': 'MENU', 'Palaak Paneer': 'MENU', 'Papadum': 'MENU'}
# 61
# {'Chicken Tikka Masala': 'MENU', 'Rice': 'MENU', 'Garlic Naan': 'MENU'}
# 25
# {'Garlic Naan Bread': 'MENU'}
# 121
# {'Tika Masala': 'MENU', 'Samasoas': 'MENU', 'Chicken Tika': 'MENU', 'Onion Rings': 'MENU'}
# 221
# {'Makhani Daal': 'MENU', 'Lentils': 'MENU', 'Matar Mushroom': 'MENU', 'Garlic Naan': 'MENU', 'Mushroom': 'MENU'}
# 205
# {'Naan': 'MENU', 'Chili Chicken': 'MENU', 'Palak Paneer': 'MENU'}
# 38
# {}
# 102
# {}
# 120
# {}
# 151
# {'Onion Rings': 'MENU', 'Indian Tamarind Sauce': 'MENU'}
# 119
# {'Chicken Tikka Masala': 'MENU', 'Tandoori Chicken': 'MENU', 'Chicken Saag': 'MENU', 'Karahi Chicken': 'MENU', 'Naan': 'MENU', 'Rice': 'MENU'}
# 147
# {'Wine': 'MENU', 'Indian Beer': 'MENU'}
# 135
# {'Lamb Shank': 'MENU'}
# 140
# {}
# 130
# {'Mango And Strawberry Lassi': 'MENU'}
# 41
# {'Lamb Chops': 'MENU', 'Goat': 'MENU'}
# 37
# {}
# 140
# {}
# 39
# {'Chicken Tikka Masala': 'MENU'}
# 38
# {}
# 46
# {}
# 43
# {}
# 167
# {'Butter Chicken': 'MENU', 'Garlic Naan': 'MENU', 'Rice': 'MENU', 'Chicken': 'MENU', 'Sauce': 'MENU', 'Curry': 'MENU', 'Garlic': 'MENU'}
# 37
# {}
# 50
# {'Marsala Ck': 'MENU', 'Rice': 'MENU'}
# 96
# {'Armaan': 'MENU', 'Chicken Kourma': 'MENU', 'Assorted Tandoori': 'MENU', 'Naan': 'MENU'}
# 106
# {'Masala': 'MENU', 'Basmati Rice': 'MENU', 'Daal': 'MENU', 'Naan': 'MENU', 'Mushroom Matar': 'MENU'}
# 38
# {'Chicken Tika Masala': 'MENU', 'Goat Roganjosh': 'MENU'}
# 64
# {'Bread': 'MENU'}
# 26
# {}
# 226
# {'Lobster Masala': 'MENU', 'Sauce': 'MENU', 'Bread': 'MENU', 'Lobster': 'MENU'}
# 208
# {'Naan': 'MENU'}
# 57
# {'Naan': 'MENU', 'Garlic Naan': 'MENU', 'Lamb Biryani': 'MENU', 'Palak Paneer': 'MENU', 'Green Chutney': 'MENU', 'Achaar': 'MENU', 'Gulab Jamun': 'MENU', 'Badami Kheer': 'MENU'}
# 309
# {'Chicken Tikka Masala': 'MENU', 'Sauce': 'MENU', 'Goat Roganjosh': 'MENU', 'Chicken Saag': 'MENU', 'Naan': 'MENU', 'Makhani Daal': 'MENU', 'Roasted Eggplant Puree': 'MENU'}
# 105
# {'Tiki Masala': 'MENU', 'Tandoori Chicken': 'MENU', 'Chai Tea': 'MENU', 'Lassi': 'MENU'}
# 249
# {'Sauces': 'MENU', 'Tamarind Sauce': 'MENU', 'Cilantro Sauce': 'MENU', 'Raita': 'MENU', 'Gulab Jamon': 'MENU'}
# 608
# {}
# 44
# {}
# 420
# {'Papadi Chaat Onion Pakora Chili Chicken Tadaka Daal Matar Mushroom Baigan Bharta Badami Kheer Gulab Jamun': 'MENU', 'Chaat': 'MENU', 'Chili Chicken': 'MENU', 'Tadaka Daal': 'MENU', 'Chick Peas': 'MENU', 'Rice': 'MENU', 'Baigan Bharta': 'MENU', 'Roasted Eggplant': 'MENU', 'Seasoned Coconut Sauce': 'MENU', 'Kheer': 'MENU', 'Gulab Jamun': 'MENU'}
# 91
# {'Lobster Masala': 'MENU'}
# 105
# {'Indian Beer': 'MENU'}
# 45
# {}
# 270
# {'Rice Pudding': 'MENU'}
# 45
# {}
# 66
# {}
# 92
# {}
# 64
# {'Marsala Ck': 'MENU', 'Rice': 'MENU'}
# 69
# {'Chicken Tiki Masala': 'MENU', 'Rice': 'MENU'}
# 328
# {'Curry': 'MENU', 'Garlic Naan': 'MENU', 'Chicken Marsala': 'MENU', 'Palak Paneer': 'MENU', 'Lamb': 'MENU', 'Goat': 'MENU', 'Mushroom': 'MENU'}
# 203
# {'Goat Curry': 'MENU', 'Chicken Curry Tandoori Chicken': 'MENU', 'Eggplant': 'MENU', 'Gulab Jamun': 'MENU', 'Rice Pudding': 'MENU'}
# 49
# {}
# 20
# {}
# 159
# {'Samosas': 'MENU'}
# 516
# {}
# 288
# {'Veggie Pakora': 'MENU', 'Channa Masala': 'MENU', 'Chicken Tikka Masala': 'MENU', 'Naan': 'MENU', 'Pakoras': 'MENU', 'Chutneys': 'MENU', 'Rice': 'MENU', 'Garlic Naan': 'MENU'}
# 58
# {'Papad': 'MENU'}
# 419
# ...
# 57
# {'Goan Curry Chicken': 'MENU', 'Garlic Naan': 'MENU'}
# 33
# {}
# 108
# {'Snacks': 'MENU', 'Tea': 'MENU'}
# 186
# {'Chatpatay': 'MENU', 'Paneer 65': 'MENU', 'Chicken Biryani': 'MENU', 'Malai Kofta': 'MENU', 'Garlic Naan': 'MENU'}
# 134
# {'Samosa': 'MENU', 'Chicken Vindaloo': 'MENU', 'Bullet Naan': 'MENU', 'Sauces': 'MENU', 'Vindaloo': 'MENU', 'Chicken': 'MENU'}
# 68
# {}
# 47
# {'Chicken 65': 'MENU'}
# 61
# {'Chatpatay': 'MENU', 'Chicken 65': 'MENU', 'Gobi Manchurian': 'MENU', 'Chicken': 'MENU', 'Gobi': 'MENU'}
# 82
# {'Malai Paneer Tikka': 'MENU'}
# 31
# {}
# 241
# {'Bharat': 'MENU', 'Chatpatay': 'MENU', 'Chaat': 'MENU', 'Samosa': 'MENU', 'Mango Papdi Chaat': 'MENU', 'Chhole Bhature': 'MENU', 'Chicken Methi': 'MENU', 'Saag Chicken': 'MENU'}
# 64
# {'Chicken Fingers': 'MENU'}
# 65
# {'Chicken 65': 'MENU', 'Garlic Naan': 'MENU', 'Samosas': 'MENU'}
# 70
# {'Chats': 'MENU', 'Pani Puris': 'MENU', 'Chicken Tikka': 'MENU', 'Biryani': 'MENU'}
# 66
# {}
# 159
# {'Gobi Manchurian': 'MENU', 'Bullet Naan': 'MENU', 'Gobi': 'MENU', 'Sauce': 'MENU', 'Chutney': 'MENU'}
# 399
# {'Mango Papdi Chaat': 'MENU', 'Plain & Gobi Paratha': 'MENU', 'Lamb Biryani': 'MENU', 'Chicken Tikka Masala': 'MENU', 'Plain Paratha': 'MENU', 'Chicken': 'MENU', 'Lamb': 'MENU', 'Raita': 'MENU', 'Gobi Paratha': 'MENU', 'Parathas': 'MENU'}
# 48
# {'Mango Chaat': 'MENU'}
# 91
# {'Lamb Kebab': 'MENU', 'Lamb Saag': 'MENU', 'Naan': 'MENU', 'Kebabs': 'MENU'}
# 80
# {'Dahi Sev Puri': 'MENU', 'Mango Papri Chat': 'MENU', 'Malai Panner Sizzler': 'MENU'}
# 39
# {'Thali': 'MENU', 'Chicken': 'MENU', 'Goat Curry': 'MENU', 'Pickles': 'MENU'}
# 166
# {'Gobi Manchurian': 'MENU', 'Rogan Josh': 'MENU'}
# 153
# {'Chatpatay': 'MENU'}
# 83
# {}
# 37
# {'Saag Shrimp': 'MENU', 'Naan': 'MENU'}
# 44
# {'Mango Papdi Chat': 'MENU', 'Dabeli': 'MENU'}
# 198
# {'Got Curry': 'MENU', 'Bullet Naan': 'MENU', 'Chicken Kabab': 'MENU', 'Beer': 'MENU'}
# 35
# {'Saag Chicken': 'MENU', 'Samosas': 'MENU'}
# 101
# {}
# 33
# {}
# 42
# {}
# 141
# {'Chicken Korma': 'MENU', 'Naan': 'MENU'}
# 177
# {'Samosa': 'MENU'}
# 97
# {}
# 33
# {'Green Sauce': 'MENU', 'Lamb': 'MENU'}
# 64
# {'Tikka Masala': 'MENU', 'Chicken Biryani': 'MENU', 'Garlic Naan': 'MENU'}
# 31
# {}
# 60
# {'Papadi Chat': 'MENU', 'Choley Bhaturey': 'MENU', 'Momos': 'MENU', 'Momos Chutney': 'MENU'}
# 49
# {'Butter Naan': 'MENU', 'Garlic Naan Bread': 'MENU', 'Chicken Masala': 'MENU'}
# 33
# {}
# 49
# {}
# 33
# {}
# 31
# {'Tandoori Chicken': 'MENU', 'Hakka Noodles': 'MENU'}
# 92
# {'Lamb Biryani': 'MENU', 'Gol Gappa Chaat': 'MENU', 'Lamb': 'MENU', 'Biryani': 'MENU', 'Mango Lassi': 'MENU'}
# 149
# {'Chatpatay': 'MENU', 'Thali': 'MENU', 'Vilas': 'MENU', 'Curry': 'MENU', 'Cake': 'MENU', 'Chaat': 'MENU', 'Snacks': 'MENU', 'Chaats': 'MENU', 'Dabeli': 'MENU', 'Potato Patty': 'MENU', 'Hamburger Bun': 'MENU'}
# 293
# {'Mango Papdi Chaat': 'MENU', 'Crispy Chips': 'MENU', 'Chutney': 'MENU', 'Gobi Manchurian': 'MENU', 'Gobi 65': 'MENU', 'Lassi': 'MENU', 'Raita': 'MENU', 'Non': 'MENU', 'Veg Thaali': 'MENU', 'Rice': 'MENU', 'Naan': 'MENU', 'Chicken': 'MENU', 'Green Lentils': 'MENU', 'Kidney Beans': 'MENU', 'Galab Jamun': 'MENU'}
# 43
# {'Platters': 'MENU'}
# 95
# {'Naan Bread': 'MENU'}
# 198
# {'Seafood': 'MENU', 'Chhole Bhature': 'MENU', 'Garbanzo Beans': 'MENU', 'Bread': 'MENU', 'Bullet Naan': 'MENU', 'Puffy Bread': 'MENU', 'Aloo Gobhi': 'MENU', 'Samosas': 'MENU', 'Chatpatay': 'MENU'}
# 52
# {}
# 111
# {'Chatpatay': 'MENU'}
# 101
# {'Chatpatay': 'MENU'}
# 64
# {}
# 153
# {'Lamb Biryani': 'MENU', 'Mango Papdi Chaat': 'MENU', 'Mango Lassi': 'MENU'}
# 59
# {'Rice Pudding': 'MENU'}
# 117
# {}
# 131
# {'Lamb Korma': 'MENU'}
# 57
# {}
# 137
# {'Malai Kofta': 'MENU', 'Garlic Naan': 'MENU', 'Curry': 'MENU'}
# 331
# {'Onion Bhajia': 'MENU', 'Onion Fritters': 'MENU', 'Chicken Pakora': 'MENU', 'Butter Chicken': 'MENU', 'Beef Curry': 'MENU', 'Vegetable Korma': 'MENU', 'Dal Makhani': 'MENU', 'Vegetable Biriyani': 'MENU', 'Salad': 'MENU', 'Papadam': 'MENU', 'Chutney': 'MENU', 'Butter Naan': 'MENU', 'Rice': 'MENU', 'Rice Pudding': 'MENU', 'Curry': 'MENU', 'Sauces': 'MENU', 'Naan': 'MENU', 'Tandoori': 'MENU', 'Rice Puddings': 'MENU'}
# 33
# {}
# 23
# {}
# 34
# {}
# 125
# {'Cucumber Salad': 'MENU', 'Butter Chicken': 'MENU', 'Soup': 'MENU', 'Aloo Gobi': 'MENU', 'Saffron Rice': 'MENU', 'Rice Pudding': 'MENU', 'Rice': 'MENU'}
# 88
# {'Mango Lassi': 'MENU', 'Butter Chicken': 'MENU', 'Tomato Chicken': 'MENU', 'Beef Samosa': 'MENU', 'Rice': 'MENU', 'Naan': 'MENU'}
# 366
# {'Lamb': 'MENU', 'Beef': 'MENU', 'Spinach': 'MENU', 'Chicken': 'MENU', 'Lentil': 'MENU', 'Chickpea': 'MENU', 'Mango Lassos': 'MENU', 'Rice Pudding': 'MENU'}
# 78
# {}
# 38
# {'Naan Bread': 'MENU'}
# 24
# {'Chicken Briyani': 'MENU'}
# 42
# {'Rice': 'MENU'}
# 43
# {'Chicken Biryani': 'MENU', 'Lamb Curry': 'MENU', 'Beef Samosa': 'MENU'}
# 206
# {'Butter Chicken': 'MENU', 'Vegetable Curry': 'MENU'}
# 82
# {'Biryani': 'MENU', 'Veal Pulao': 'MENU'}
# 157
# {'Chicken': 'MENU', 'Beef': 'MENU', 'Goat': 'MENU', 'Fish': 'MENU', 'Biryani': 'MENU', 'Rice': 'MENU', 'Rotis': 'MENU', 'Achari Chicken': 'MENU', 'Fish Pakoras': 'MENU'}
# 136
# {'Rice': 'MENU', 'Chicken Pieces': 'MENU', 'Sauces': 'MENU'}
# 415
# {'Silver Spoon': 'MENU', 'Silver': 'MENU', 'Nihari': 'MENU', 'Haleem': 'MENU', 'Biryanis': 'MENU', 'Sindhi Biryani': 'MENU', 'Naan': 'MENU', 'Butter Naan': 'MENU', 'Stew': 'MENU', 'Samosas': 'MENU', 'Chicken': 'MENU', 'Lollypop Chicken': 'MENU', 'Shami Kabab': 'MENU', 'Fish': 'MENU', 'Fingerfish': 'MENU'}
# 873
# {}
# 75
# {'Biryani': 'MENU'}
# 81
# {}
# 190
# {}
# 185
# {'Shami Kabab': 'MENU', 'Curry': 'MENU'}
# 103
# {'Rice': 'MENU', 'Butter Chicken': 'MENU', 'Chicken Tikka Masala': 'MENU', 'Paratha': 'MENU', 'Chicken Tikka': 'MENU'}
# 58
# {'Biryani': 'MENU'}
# 247
# {'Sauce': 'MENU', 'Salad': 'MENU', 'Butter Chicken': 'MENU', 'Palak Paneer': 'MENU', 'Yogurt': 'MENU', 'Veal Biryani': 'MENU'}
# 60
# {'Kabab Rolls': 'MENU', 'Biryani': 'MENU', 'Samosas': 'MENU'}
# 27
# {'Baingun': 'MENU'}
# 67
# {}
# 46
# {'Naan': 'MENU', 'Nihari': 'MENU'}
# 114
# {}
# 130
# {'Butter Chicken': 'MENU', 'Chicken Tikka Masala': 'MENU', 'Curry': 'MENU', 'Naans': 'MENU', 'Rice': 'MENU'}
# 75
# {'Butter Chicken': 'MENU', 'Channa Masala': 'MENU', 'Naan': 'MENU'}
# 83
# {}
# 71
# {'Rice': 'MENU'}
# 37
# {'Samosas': 'MENU'}
# 41
# {'Chicken Biryani': 'MENU', 'Lamb Biryani': 'MENU'}
# 129
# {}
# 33
# {'Butter Chicken': 'MENU'}
# 229
# {'Chicken Biryani': 'MENU', 'Goat Biryani': 'MENU', 'Naan': 'MENU', 'Chicken Tikka Masala': 'MENU', 'Goat Biyani': 'MENU', 'Butter Chicken': 'MENU', 'Biryani': 'MENU'}
# 30
# {'Biryani': 'MENU'}
# 127
# {}
# 82
# {}
# 69
# {'Raita': 'MENU'}
# 45
# {'Naan': 'MENU'}
# 44
# {}
# 228
# {'Butter Chicken': 'MENU', 'Curry': 'MENU', 'Chicken Biriyani': 'MENU', 'Yogurt': 'MENU', 'Tandoori Naan': 'MENU', 'Naan': 'MENU'}
# 25
# {}
# 45
# {'Biryani': 'MENU'}
# 166
# {'Veal Biriyani Chicken Biriyani Chicken Korma Lamb Curry Naan': 'MENU'}
# 236
# {'Biryani': 'MENU', 'Curry': 'MENU'}
# 23
# {'Superb Biryanis': 'MENU'}
# 94
# {'Goat Briyani': 'MENU', 'Briyani': 'MENU', 'Chicken Qourma': 'MENU'}
# 68
# {'Biryani': 'MENU'}
# 164
# {'Chicken Biryani': 'MENU', 'Nihari': 'MENU', 'Lentil': 'MENU', 'Haleem': 'MENU', 'Nan Bread': 'MENU', 'Bread': 'MENU'}
# 162
# {}
# 117
# {'Pickled Hot Sauce': 'MENU', 'Biryani': 'MENU'}
# 89
# {'Chicken Biryani': 'MENU', 'Tandoori Leg': 'MENU', 'Fish Pakora': 'MENU', 'Beef Kebab': 'MENU', 'Chicken Marsala': 'MENU', 'Butter Chicken': 'MENU', 'Biryani': 'MENU'}
# 61
# {'Chicken Biryani': 'MENU'}
# 23
# {'Chicken Biryani': 'MENU', 'Butter Chicken': 'MENU'}
# 37
# {'Chicken Biriyani': 'MENU', 'Boneless Chicken Tikka': 'MENU'}
# 93
# {'Chicken Biryani': 'MENU', 'Chicken Butter Chicken': 'MENU', 'Chicken': 'MENU', 'Naan': 'MENU'}
# 67
# {}
# 154
# {'Kabob Roll': 'MENU'}
# 133
# {'Chicken': 'MENU'}
# 153
# {'Lamb Karahi': 'MENU', 'Naan': 'MENU', 'Fried Fish': 'MENU'}
# 181
# {'Halwa - Puri': 'MENU', 'Samosas': 'MENU', 'Shammi Kebab': 'MENU', 'Channa': 'MENU', 'Butter Chicken': 'MENU', 'Chicken': 'MENU', 'Karhai Chicken': 'MENU', 'Sauce': 'MENU'}
# 45
# {'Naan': 'MENU', 'Naans': 'MENU'}
# 224
# {'Tandoori Chicken Pieces': 'MENU', 'Chicken Briyani': 'MENU', 'Veal Biryani': 'MENU', 'Achari Chicken': 'MENU', 'Mutton Qorma': 'MENU', 'Butter Chicken': 'MENU', 'Tandoori Chicken': 'MENU', 'Chicken Pakora': 'MENU', 'Palak Paneer': 'MENU', 'Rasmalai': 'MENU', 'Mango Delight': 'MENU', 'Tandoori Naan': 'MENU', 'Fresh Garden Salad': 'MENU', 'Yogurt Sauce': 'MENU'}
# 428
# {'Chicken Biryani': 'MENU', 'Mutton': 'MENU', 'Bone': 'MENU', 'Sauce': 'MENU', 'Chicken': 'MENU', 'Matar Paneer': 'MENU', 'Paneer': 'MENU'}
# 26
# {}
# 41
# {}
# 200
# {'Biryani': 'MENU', 'Biryanis': 'MENU', 'Masala': 'MENU', 'Kewra': 'MENU', 'Fried Fish': 'MENU', 'Chicken Malai Boti': 'MENU', 'Karhai Chicken': 'MENU', 'Th Biryani': 'MENU', 'Chicken Biryani': 'MENU', 'Veal': 'MENU', 'Beef': 'MENU', 'Fish': 'MENU', 'Chicken': 'MENU'}
# 257
# {'Rice': 'MENU', 'Curry': 'MENU', 'Butter Chicken': 'MENU'}
# 80
# {'Chicken Biryani': 'MENU', 'Rice': 'MENU', 'Biryani': 'MENU'}
# 56
# {}
# 23
# {}
# 43
# {'Beef Samosas': 'MENU'}
# 67
# {'Lollipop Chicken': 'MENU', 'Butter Chicken': 'MENU', 'Biryani Rice': 'MENU'}
# 50
# {'Haleem': 'MENU', 'Biryani': 'MENU'}
# 134
# {'Nihari': 'MENU', 'Butter Chicken': 'MENU', 'Seekh Kabob': 'MENU', 'Chicken Tikka': 'MENU', 'Nan': 'MENU', 'Naans': 'MENU', 'Naan': 'MENU'}
# 57
# {'Haleem': 'MENU'}
# 60
# {}
# 67
# {'Tandoori Chicken': 'MENU', 'Kebabs': 'MENU'}
# 55
# {'Lollipop Chicken': 'MENU', 'Lamb': 'MENU', 'Lamb Curry': 'MENU'}
# 76
# {'Chicken Lollipops': 'MENU', 'Fried Fish': 'MENU', 'Chicken Biryani': 'MENU', 'Goat Curry': 'MENU', 'Chicken Lollipop': 'MENU'}
# 49
# {'Biryani': 'MENU', 'Curry': 'MENU'}
# 86
# {'Seekh Kababs': 'MENU', 'Reshmi Kababs': 'MENU', 'Green Chutney': 'MENU'}
# 30
# {'Chicken Biryani': 'MENU', 'Butter Chicken': 'MENU'}
# 41
# {}
# 87
# {}
# 150
# {'Chicken Korma': 'MENU', 'Butter Naan': 'MENU', 'Kebabs': 'MENU', 'Curries': 'MENU', 'Chicken': 'MENU', 'Veal Korma': 'MENU', 'Seekh Kebab Masala Curry': 'MENU'}
# 83
# {'Fish': 'MENU', 'Biryani': 'MENU'}
# 57
# {}
# 56
# {'Biryani': 'MENU'}
# 40
# {'Kebabs': 'MENU', 'Tikkas': 'MENU', 'Wings': 'MENU', 'Fish': 'MENU'}
# 86
# {}
# 193
# {'Karahi Chicken': 'MENU', 'Rice': 'MENU'}
# 168
# {'Biryani': 'MENU', 'Channa Masala': 'MENU', 'Palak Paneer': 'MENU', 'Muttor': 'MENU', 'Chicken Biryani': 'MENU'}
# 30
# {}
# 100
# {'Veal Biryani': 'MENU', 'Fish': 'MENU', 'Chicken': 'MENU', 'Biryani': 'MENU'}
# 34
# {}
# 79
# {'Fried Fish': 'MENU', 'Fish': 'MENU', 'Naan': 'MENU'}
# 71
# {'Biryani': 'MENU', 'Veg Biryani': 'MENU', 'Plain Rice': 'MENU', 'Chicken Biryani': 'MENU'}
# 411
# {'Fried Bread': 'MENU', 'Naan': 'MENU', 'Puris': 'MENU', 'Naans': 'MENU'}
# 234
# {'Chicken Nasi Biryani': 'MENU', 'Biryanis': 'MENU', 'Naan Bread': 'MENU', 'Goat': 'MENU', 'Lamb Curry': 'MENU'}
# 225
# {'Chicken': 'MENU', 'Tandoori': 'MENU', 'Achari Chicken': 'MENU', 'Biriyani': 'MENU', 'Butter Chicken': 'MENU'}
# 75
# {}
# 69
# {'Chicken Briyani': 'MENU', 'Butter Chicken': 'MENU', 'Lollipop Chicken': 'MENU'}
# 125
# {'Chicken Patty': 'MENU', 'Chicken': 'MENU', 'Patty': 'MENU', 'Veal Korma': 'MENU', 'Seekh Kebab Masala Veal Korma': 'MENU', 'Seekh Kebab Masala': 'MENU', 'Seekh Kebab Mixed': 'MENU', 'Naans': 'MENU'}
# 53
# {}
# 41
# {'Butter Naan': 'MENU', 'Butter Chicken': 'MENU', 'Lollipop Chicken': 'MENU'}
# 125
# {}
# 369
# {'Tandoori': 'MENU', 'Chicken Tikka': 'MENU', 'Chicken Biryani': 'MENU', 'Tandoor': 'MENU', 'Rice': 'MENU', 'Chicken': 'MENU'}
# 84
# {'Butter Chicken': 'MENU', 'Biryani': 'MENU', 'Chicken Lollipop': 'MENU'}
# 102
# {'Fish': 'MENU', 'Nihari': 'MENU', 'Beef': 'MENU', 'Basa': 'MENU', 'Chicken': 'MENU'}
# 88
# {}
# 255
# {'Biryani Rice': 'MENU', 'Diff Curry': 'MENU', 'Butter Chickens': 'MENU', 'Naan': 'MENU', 'Butter Chicken': 'MENU', 'Naans': 'MENU', 'Curry Meat': 'MENU'}
# 53
# {}
# 171
# {'Naan': 'MENU', 'Naans': 'MENU', 'Naan Bread': 'MENU'}
# 388
# {'Rice': 'MENU', 'Chicken Biryani': 'MENU', 'Chicken': 'MENU', 'Kabab Roll': 'MENU', 'Salad': 'MENU', 'Kabab': 'MENU', 'Naan': 'MENU', 'Roll': 'MENU', 'Bar Bq Chicken': 'MENU', 'Baked Chicken': 'MENU', 'Grilled Chicken': 'MENU', 'Naans': 'MENU', 'Lollipop Chicken': 'MENU', 'Fish Pakoras': 'MENU', 'Biryani': 'MENU'}
# 192
# {'Veggie Biryani': 'MENU', 'Channa Masala': 'MENU', 'Biryani': 'MENU', 'Channa': 'MENU', 'Lentils': 'MENU', 'Sauce': 'MENU'}
# 105
# {'Chicken Biryani': 'MENU', 'Biryani': 'MENU', 'Yogurt': 'MENU', 'Raita': 'MENU', 'Rice': 'MENU'}
# 82
# {}
# 222
# {'Sauce': 'MENU'}
# {'Dosa': 'MENU', 'Guthi Vonkaya Kura Peshwari Chana': 'MENU', 'Rice': 'MENU', 'Raita': 'MENU', 'Curries': 'MENU', 'Kura': 'MENU', 'Stuffed Indian Eggplant': 'MENU', 'Chana': 'MENU', 'Kerala Fish Curry': 'MENU', 'Chicken Tikka Masala': 'MENU', 'Okra Curry': 'MENU', 'Dal': 'MENU', 'Naan': 'MENU', 'Curry': 'MENU', 'Crispy Pakoras': 'MENU', 'Veg Biriyani': 'MENU', 'Mushroom Peas Masala Curry': 'MENU', 'Sambar': 'MENU', 'Dosas': 'MENU', 'Mirch Curry': 'MENU', 'Chicken 65': 'MENU', 'Andhra Chicken Curry': 'MENU', 'Spice South Chicken Curry': 'MENU', 'Biriyani': 'MENU', 'Chicken': 'MENU', 'Vegetable Curry': 'MENU', 'Biryani': 'MENU', 'Vegetables': 'MENU', 'Lamb': 'MENU', 'Goat': 'MENU', 'Tikki Marsala': 'MENU', 'Naan Bread': 'MENU', 'Masala Dosa': 'MENU', 'Chicken Chettinad': 'MENU', 'Panir Butter Masala': 'MENU', 'Garlic Nan': 'MENU', 'Papadums': 'MENU', 'Chutney': 'MENU', 'Indian Beers': 'MENU', 'Goat Curry': 'MENU', 'Chicken Tandoori': 'MENU', 'Beef Vindaloo': 'MENU', 'Palak Paneer': 'MENU', 'Eer': 'MENU', 'Vegetable Pakoras': 'MENU', 'Butter Chicken': 'MENU', 'Parathas': 'MENU', 'Buttery Parathas': 'MENU', 'Kabab': 'MENU', 'Mutton Karhai': 'MENU', 'Mutton': 'MENU', 'Chicken Tikka': 'MENU', 'Nan': 'MENU', 'Roti': 'MENU', 'Naans': 'MENU', 'Mushroom Masala': 'MENU', 'Mushrooms': 'MENU', 'Butter & Tandoori Chicken': 'MENU', 'Seafood': 'MENU', 'Fish': 'MENU', 'Pani Puri': 'MENU', 'Pani Puris': 'MENU', 'Salads': 'MENU', 'Chicken Biryani': 'MENU', 'Ras Malai': 'MENU', 'Aloo Gobi': 'MENU', 'Paneer Makhani': 'MENU', 'Pickles': 'MENU', 'Gulab Jamon': 'MENU', 'Makhni Dahl': 'MENU', 'Pakora': 'MENU', 'Tandoori Chicken': 'MENU', 'Pasta': 'MENU', 'Potato / Cauliflower Curry': 'MENU', 'Perience': 'MENU', 'Butter Chicken Sauce': 'MENU', 'Ice Cream': 'MENU', 'Rice Pudding': 'MENU', 'Gulabjam': 'MENU', 'Pakoras': 'MENU', 'Chicken Breast': 'MENU', 'Chili Chicken': 'MENU', 'Chicken Curry': 'MENU', 'Chicken Biryani Combo': 'MENU', 'Veggie Samosas': 'MENU', 'Spicy Chicken': 'MENU', 'Chicken Birani': 'MENU', 'Chicken Samosa': 'MENU', 'Kothu Roti': 'MENU', 'Coconut Roti': 'MENU', 'Rice Noodle': 'MENU', 'Yellow Thin Noodles': 'MENU', 'Snacks': 'MENU', 'Samosas': 'MENU', 'Rolls': 'MENU', 'Idllis': 'MENU', 'Noodles': 'MENU', 'Rotis': 'MENU', 'Hot Rolls': 'MENU', 'Samosa': 'MENU', 'Tomato Rice': 'MENU', 'Crispy Masala Fried Corn': 'MENU', 'Boiled Egg': 'MENU', 'Sauce': 'MENU', 'Fruit Custard': 'MENU', 'Yogurt Sauce': 'MENU', 'Gobi': 'MENU', 'Chana Masala': 'MENU', 'Sauces': 'MENU', 'Fried Cauliflower': 'MENU', 'Malai Kofta': 'MENU', 'Saag Paneer': 'MENU', 'Plain Rice': 'MENU', 'Saag': 'MENU', 'Chai': 'MENU', 'Dosa Dinner': 'MENU', 'Butter Masala': 'MENU', 'Shrimp Curry': 'MENU', 'Tandoor Chicken': 'MENU', 'Mysore Masala Dosa': 'MENU', 'Chana Batura': 'MENU', 'Batura': 'MENU', 'Gobi 65': 'MENU', 'Paneer': 'MENU', 'Indian Cheese': 'MENU', 'Ravaa Dosa': 'MENU', 'Lentil Soup': 'MENU', 'Cheese Bread': 'MENU', 'Beer': 'MENU', 'Wine': 'MENU', 'Sushi': 'MENU', 'Chicken Masala And Curry': 'MENU', 'Eggplant': 'MENU', 'Charts': 'MENU', 'Bread Pudding': 'MENU', 'Egg Bhurji': 'MENU', 'Egg Dosas': 'MENU', 'Mimosas': 'MENU', 'Uthappam': 'MENU', 'Chole Batura': 'MENU', 'Idli': 'MENU', 'Veg Dosas': 'MENU', 'Masala Dosa Guntur Masala Dosa Mysore Masala Dosa Ghee Dosa Plain Dosa Spring Noodles Dosa Non - Veg Dosas': 'MENU', 'Omelet Dosa Kodi Vepudu Dosa Lamb Sukka Dosa Kids Dosas': 'MENU', 'Butter Chicken Dosa': 'MENU', 'Chai Tea': 'MENU', 'Dalpuri': 'MENU', 'Aloo Chana': 'MENU', 'Tomatoes Choka': 'MENU', 'Fried Fish Sandwich': 'MENU', 'Doubles': 'MENU', 'Boneless Goat': 'MENU', 'Aloo Pie': 'MENU', 'Pholourie': 'MENU', 'Boneless Goat Roti': 'MENU', 'Currants Roll': 'MENU', 'Kurma': 'MENU', 'Curry Goat': 'MENU', 'Goat Curry Roti': 'MENU', 'Goat Roti': 'MENU', 'Paratha': 'MENU', 'Chicken Doubles': 'MENU', 'Chicken Roti': 'MENU', 'Pepper Sauce': 'MENU', 'Okra': 'MENU', 'Goat Dhalpourie Roti': 'MENU', 'Lena': 'MENU', 'Oti': 'MENU', 'Dhal Roti': 'MENU', 'Channa': 'MENU', 'Aloo': ' ...

# %%
output_path = "./data/output/"
ner_pickles_op = output_path + "ner/"
cr_pickles_op = output_path + "cr/"

''' read restaurant knowledgebase data '''
knowledge_base_entities = r"data/kb/entities/"
kb_restaurant_file = knowledge_base_entities + "restaurant.csv"
kb_menu_file = knowledge_base_entities + "menu.csv"
kb_menu_file1 = knowledge_base_entities + "menu1.csv"
kb_general_file = knowledge_base_entities + "general.csv"
kb_restaurant_aspects_file = knowledge_base_entities + "restaurant_aspects.csv"
kb_menu_aspects_file = knowledge_base_entities + "menu_attrs.csv"

entity_headers = ['Name', 'Label']

# %%
''' Add restaurants to `kb_restaurant_file` '''

data = []
for restaurant in restaurant_data['restaurants']:
    data.append((restaurant['name'], 'RESTAURANT'))

rest_data_df = pd.DataFrame(data, columns=['Name', 'Label']).drop_duplicates()
rest_data_df.to_csv(kb_restaurant_file, index=False)

# %%
''' Fixed some MENU entiies manually '''

''' Remove Duplicate entities from MENU file '''
df = pd.read_csv(kb_menu_file, sep=",")
df.drop_duplicates(subset=None, inplace=True)
df.to_csv(kb_menu_file1, index=False)

# %%
''' make dataframes for kb '''
kb_restaurant_df = pd.read_csv(kb_restaurant_file, header=0, names=entity_headers)
kb_menu_df = pd.read_csv(kb_menu_file, header=0, names=entity_headers)
# kb_general_df = pd.read_csv(kb_general_file, header=0, names=['Name', 'Label'])
kb_restaurant_aspects_df = pd.read_csv(kb_restaurant_aspects_file, header=0, names=entity_headers)
kb_menu_aspects_df = pd.read_csv(kb_menu_aspects_file, header=0, names=entity_headers)
# print(kb_restaurant_aspects_df)

# %%
''' Insert Menus in Neo4J database '''
graph = GraphDB("bolt://localhost:7687", "neo4j", "erclab")

kb_menu_df_distinct = kb_menu_df.drop_duplicates()

for i in kb_menu_df_distinct.index:
    
    menu_name = kb_menu_df_distinct['Name'][i]
    menu_id_arr = menu_name.lower().split()
    menu_id = "_".join(id for id in menu_id_arr)

    # Inserting menus
    graph.create_menu(menu_id, menu_name)

graph.close()

# %%
''' Insert Aspects in Neo4J database '''
graph = GraphDB("bolt://localhost:7687", "neo4j", "erclab")

kb_restaurant_aspects_df_distinct = kb_restaurant_aspects_df.drop_duplicates()

for i in kb_restaurant_aspects_df_distinct.index:
    
    aspect_name = kb_restaurant_aspects_df_distinct['Name'][i]
    aspect_id_arr = aspect_name.lower().split()
    aspect_id = "_".join(id for id in aspect_id_arr)

    # Inserting menus
    graph.create_aspect(aspect_id, aspect_name)

graph.close()

# %%
''' open cleaned restaurant dataset '''
restaurant_cleaned_reviews_file = r"data/input/cleaned_reviews.json"
file = open(restaurant_cleaned_reviews_file,)
restaurant_cleaned_reviews = json.load(file)
file.close()

# %%
''' coreference resolution '''
allen_cr = AllenCR(True)
predictor, nlp = allen_cr.load_models()

i=0
for restaurant in restaurant_cleaned_reviews['restaurants']:

    reviews = restaurant['reviews']
    for review in reviews:
        dummy_sentence = review["name"] + " visit " + restaurant["name"] + "."
        doc = dummy_sentence + " " + review["text"]
#         print(review["text"])
        clusters = predictor.predict(doc)['clusters']
        nlp_doc = nlp(doc)
        coref_resolved = allen_cr.improved_replace_corefs(nlp_doc, clusters)
        
        ## split doc into sentences and remove first sentence
        #     # nlp_small.add_pipe(nlp_small.create_pipe('sentencizer'))
        nlp_doc = nlp(coref_resolved)
        sentences = [sent.string.strip() for sent in nlp_doc.sents]
        ## remove dumy_sentence
        sentences.pop(0)
        rev = " ".join([sent for sent in sentences])
        review["text"] = rev
        
#         print('resolved')
#         print(review['text'])

# print(restaurant_cleaned_reviews['restaurants'][0]['reviews'][0]['text'])
# Out:
# [AllenCR] Initializing...
# [AllenCR] Loading model from: https://storage.googleapis.com/allennlp-public-models/coref-spanbert-large-2020.02.27.tar.gz
# Some weights of BertModel were not initialized from the model checkpoint at SpanBERT/spanbert-large-cased and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [AllenCR] Model loaded successfully...

# %%
rest_obj = dict()
rest_obj['restaurants'] = restaurant_cleaned_reviews['restaurants']
with open('data/input/coref_resolved_reviews.json', 'w') as outfile:
    json.dump(rest_obj, outfile)

# %%
kb_restaurant_dict = {}
kb_restaurant_aspects_dict = {}
kb_menu_dict = {}
# kb_menu_aspects_dict = {}
kb_general_dict = {}

''' read restaurant NER dictionary '''
with open(kb_restaurant_file, mode='r') as infile:
    reader = csv.reader(infile)
    i = 0
    for rows in reader:
        if i == 0:
            i += 1
            continue
        kb_restaurant_dict[rows[0]] = rows[1]

''' read restaurant aspects NER dictionary '''
with open(kb_restaurant_aspects_file, mode='r') as infile:
    reader = csv.reader(infile)
    i = 0
    for rows in reader:
        if i == 0:
            i += 1
            continue
        kb_restaurant_aspects_dict[rows[0]] = rows[1]

''' read menu NER dictionary '''
with open(kb_menu_file, mode='r') as infile:
    reader = csv.reader(infile)
    i = 0
    for rows in reader:
        if i == 0:
            i += 1
            continue
        kb_menu_dict[rows[0]] = rows[1]

# %%
lexicon_file_path = 'data/opinion_lexicon-en/'

def load_opinion_lexicon():
    # Load opinion lexicon
    neg_file = open(lexicon_file_path + "negative-words.txt", encoding="ISO-8859-1")
    pos_file = open(lexicon_file_path + "positive-words.txt", encoding="ISO-8859-1")
    neg = [line.strip() for line in neg_file.readlines()]
    pos = [line.strip() for line in pos_file.readlines()]
    opinion_words = neg + pos
    return opinion_words, pos, neg

def process_triple_pruning(triples, rest_id, review, ner_dict):
    # entity_set = set(ner_dict.keys())
    final_triples = []

    for row, col in triples.iterrows():
        col['subject'] = col['subject'].strip()
        col['object'] = col['object'].strip()

        ''' Fixing Misspelling Menus '''
        valid_menu = False
        for key, value in kb_menu_dict.items():
            if key.lower() == col['subject'].lower():
                valid_menu = True
                break
                
        if not valid_menu:
            for key, value in kb_menu_dict.items():
                subject_ratio = levenshtein_ratio_and_distance(key.lower(), col['subject'].lower(), ratio_calc=True)
                if subject_ratio > 0.85:
    #                 key_id = "_".join(k for k in key.split())
                    print("updating subject ["+col['subject']+"] with ["+key+"]")
                    col['subject'] = key
        
        valid_menu = False
        for key, value in kb_menu_dict.items():
            if key.lower() == col['object'].lower():
                valid_menu = True
                break

        if not valid_menu:
            for key, value in kb_menu_dict.items():
                object_ratio  = levenshtein_ratio_and_distance(key.lower(), col['object'].lower(), ratio_calc=True)
                if object_ratio > 0.85:
    #                 key_id = "_".join(k for k in key.split())
                    print("updating object [" + col['object'] + "] with [" + key + "]")
                    col['object'] = key
        
        ''' check if subject is a valid entity '''
        valid_subject = False
        restaurant_subject = False
        for key, value in kb_restaurant_dict.items():
            if key.lower() == col['subject'].lower():
                col['subject'] = rest_id
                restaurant_subject = True
                valid_subject = True
                break

        menu_subject = False
        if not restaurant_subject:
            for key, value in kb_menu_dict.items():
                if key.lower() == col['subject'].lower():
                    menu_id = "_".join(k for k in col['subject'].split())
                    col['subject'] = menu_id
                    menu_subject = True
                    valid_subject = True
                    break
        
        user_subject = False
        if not menu_subject:
            if review['name'].lower() == col['subject'].lower():
                col['subject'] = review['user_id']
                user_subject = True
                valid_subject = True

                    
        general_subject = False
        if not user_subject:
            for key, value in ner_dict.items():
                if key.lower() == col['subject'].lower():
                    general_subject = True
                    valid_subject = True
                    break

        res_aspect_subject = False
        if not general_subject:
            for key, value in kb_restaurant_aspects_dict.items():
                if key.lower() == col['subject'].lower():
                    aspect_id = "_".join(k for k in col['subject'].split())
                    col['subject'] = aspect_id
                    res_aspect_subject = True
                    valid_subject = True
                    break

        # menu_aspect_subject = False
        # if not general_subject:
        #     for key, value in kb_menu_aspects_dict.items():
        #         if key.lower() == col['subject'].lower():
        #             menu_aspect_subject = True
        #             valid_subject = True
        #             break

        ''' check if object is a valid entity '''
        valid_object = False
        restaurant_object = False
        for key, value in kb_restaurant_dict.items():
            if key.lower() == col['object'].lower():
                col['object'] = rest_id
                restaurant_object = True
                valid_object = True
                break

        menu_object = False
        if not restaurant_object:
            for key, value in kb_menu_dict.items():
                if key.lower() == col['object'].lower():
                    menu_id = "_".join(k for k in col['object'].split())
                    col['object'] = menu_id
                    menu_object = True
                    valid_object = True
                    break

        user_object = False
        if not menu_object:
            if review['name'].lower() == col['object'].lower():
                col['object'] = review['user_id']
                user_object = True
                valid_object = True
                
        general_object = False
        if not user_object:
            for key, value in ner_dict.items():
                if key.lower() == col['object'].lower():
                    general_object = True
                    valid_object = True
                    break

        res_aspect_object = False
        if not general_object:
            for key, value in kb_restaurant_aspects_dict.items():
                if key.lower() == col['object'].lower():
                    aspect_id = "_".join(k for k in col['object'].split())
                    col['object'] = aspect_id
                    res_aspect_object = True
                    valid_object = True
                    break

        attr_obj = False
        if not res_aspect_object:
            opinion_words, pos, neg = load_opinion_lexicon()
            if col['object'].lower() in opinion_words:
                attr_obj = True
                valid_object = True

#         print(col['subject']+" : "+col['object']+" : "+str(valid_subject)+" : "+str(valid_object))
        if valid_subject and valid_object:
            if menu_subject:
                final_triples.append(('Node', rest_id, 'has_menu', 'Node', col['subject']))
            if restaurant_subject and menu_object:
                col['relation'] = 'has_menu'
            if res_aspect_subject and (res_aspect_object or attr_obj):
                col['relation'] = 'is'
            final_triples.append(('Node', col['subject'], col['relation'], 'Node', col['object']))

    triple_df = pd.DataFrame(final_triples, columns=['Type1', 'Entity1', 'Relationship', 'Type2', 'Entity2'])\
        .drop_duplicates()
    return triple_df

# %%
''' make general NER list '''

triples_df = pd.DataFrame()

rest_index=0
rest_count = len(restaurant_cleaned_reviews['restaurants'])
for restaurant in restaurant_cleaned_reviews['restaurants']:
    
    rest_index += 1
    print("Processing Restaurant "+str(rest_index)+"/"+str(rest_count))
    
    reviews = restaurant['reviews']
    
    rev_index=0
    rev_count = len(reviews)
    for review in reviews:
        
        rev_index +=1
        print("\t Processing Review "+str(rev_index)+"/"+str(rev_count))
        
#         if rev_index < 6:
#             continue
            
        ner_dict = {}
        doc = nlp(review["text"])

        for x in doc.ents:
            entity_span = x.text

            has_restaurant_entity = False
            i = 0
            for kb_restaurant in kb_restaurant_df['Name']:
                ratio = levenshtein_ratio_and_distance(kb_restaurant.lower(), entity_span.lower(), ratio_calc=True)
                if ratio > 0.85:
                    has_restaurant_entity = True
                if has_restaurant_entity:
                    break
                i += 1

            if has_restaurant_entity:
                continue

            has_menu_entity = False
            i = 0
            for kb_menu in kb_menu_df['Name']:
                ratio = levenshtein_ratio_and_distance(kb_menu.lower(), entity_span.lower(), ratio_calc=True)
                # print(menu.lower(), entity_span.lower(), str(ratio))
                if ratio > 0.85:
                    has_menu_entity = True
                if has_menu_entity:
                    break
                i += 1

            if has_menu_entity:
                continue

            ner_dict[x.text] = x.label_

#         ner_dict

#         with open(kb_general_file, 'a') as f_object:
#             dictwriter_object = csv.writer(f_object)
#             for key, value in ner_dict.items():
#                 dictwriter_object.writerow([key, value])
#             f_object.close()

#         # opening the csv file in 'w' mode
#         general_file = open(kb_general_file, 'w')

#         with general_file:
#             writer = csv.DictWriter(general_file, fieldnames=entity_headers)

#             writer.writeheader()
#             for key, value in ner_dict.items():
#                 writer.writerow({entity_headers[0]: key,
#                                  entity_headers[1]: value})
        
        text = review["text"]
        tuple_pairs = get_lexical_triplets_pairs(text)
        tuple_pairs_df = pd.DataFrame(tuple_pairs, columns=['subject', 'relation', 'object'])
        # pairs = list(set(tuple(sub) for sub in tuple_pairs))
        tuple_pairs_prune = process_triple_pruning(tuple_pairs_df, restaurant['rest_id'], review, ner_dict)
        triples_df = pd.concat([triples_df,tuple_pairs_prune])
#         if rev_index == 7:
#             break
#     break

print(triples_df)
# Out:
# Processing Restaurant 1/100
# 	 Processing Review 1/20
# 	 Processing Review 2/20
# 	 Processing Review 3/20
# 	 Processing Review 4/20
# 	 Processing Review 5/20
# 	 Processing Review 6/20
# updating subject [Dosas] with [Dosa]
# updating subject [Dosa] with [Dhosa]
# updating subject [veg biriyani] with [Veg Biryani]
# updating subject [Veg Biryani] with [Vege Biryani]
# updating subject [Vege Biryani] with [Veggie Biryani]
# 	 Processing Review 7/20
#   Type1                   Entity1 Relationship Type2                   Entity2
# 0  Node  u-viDOnsL8pW6A-HEAf_VXXQ    recommend  Node  b-LZWXP-D4YPlzsFjVx6b9XA
# 1  Node  b-LZWXP-D4YPlzsFjVx6b9XA     has_menu  Node            Veggie_Biryani
# 2  Node            Veggie_Biryani          was  Node                flavourful
# 3  Node  b-LZWXP-D4YPlzsFjVx6b9XA     has_menu  Node              masala_curry
# 4  Node              masala_curry          was  Node                     great
# 5  Node  b-LZWXP-D4YPlzsFjVx6b9XA     has_menu  Node                    sambar
# 6  Node                    sambar          was  Node                     tasty
# 7  Node                   service           is  Node                   helpful
# 0  Node  b-LZWXP-D4YPlzsFjVx6b9XA     has_menu  Node             chicken_curry
# 1  Node             chicken_curry           is  Node                delectable
# 2  Node                   service           is  Node                      good
